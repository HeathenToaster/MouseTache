# %% [markdown]
# # Notebook For Figure 2 Method Paper

# %% [markdown]
# ### Imports
# All functions are in behavior_analysis_functions.py

# %%
import os
import glob
from processing_TowerCoordinates import *
from processing_session_trajectory import *
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import matplotlib.path as mpath
import matplotlib.cm as cm
import matplotlib.patches as patches
from matplotlib.gridspec import GridSpec
from matplotlib.colors import Normalize
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np
import pickle
import scipy.ndimage as ndimage
from scipy.stats import wilcoxon
from processing_TowerCoordinates import *
from datetime import date
from scipy.ndimage import gaussian_filter as smooth
import matplotlib.colors as mcolors

import warnings 
from matplotlib.colors import LinearSegmentedColormap


plt.style.use('paper.mplstyle')

#from PlottingFunctions import *

# %% [markdown]
# # Getting mice data
# Define the folder where your MOUXXX folder are, generate a list of MOUXXX folders and for each mice a list of sessions

# %%
# Finding and importing data

# indicate where the data are
# path_to_data_folder is the path of the folder where you store your different mice.

# Windows:
# path_to_data_folder='C:'+os.sep+'Users'+os.sep+'MORVAN'+os.sep+'Documents'+os.sep+'patchouris'+os.sep+'Sample_Data'+os.sep
# Linux:
# path_to_data_folder '/home/david/Documents/Code/ForagingProject/Patchouris/patchouris/Sample_Data/'
# MacOs
#path_to_data_folder = '/Users/davidrobbe/Documents/Science/Data/ForagingMice/'


#path_to_data_folder='/home/david/Documents/David/Data/'
#path_to_data_folder='/LocalData/ForagingMice/JAK2Data'
#path_to_data_folder='/LocalData/ForagingMice/MaudData'
path_to_data_folder='/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData'
#path_to_data_folder = '/Users/davidrobbe/Documents/Science/Data/ForagingMice/KenzaData'


pattern_of_MOU_Folders = os.path.join(path_to_data_folder, "MOU*")

# List all mice in the data folder (If you want to process all the mice in your data folder),
mice_list = [os.path.basename(path) for path in glob.glob(pattern_of_MOU_Folders)]
mice_list=sorted(mice_list)

# Print the number of mice, the list of mice, and add an empty line
print(f'Found {len(mice_list)} {"mice" if len(mice_list) > 1 else "mouse"} in the data folder: {", ".join(mice_list)}\n')


#If you want to process a subset of mice uncomment the line below and comment the 2 lines above

#mice_list: list[str] = ["MOU2334"]  # For processing  a single mice. Equivalent to mice_list = ["MOU2334"] but more correct as it forces to create a list of string
#mice_list=['MOU2329', 'MOU2330', 'MOU2331', 'MOU2332', 'MOU2333', 'MOU2334']
#print(f'Found {len(mice_list)} {"mice" if len(mice_list) > 1 else "mouse"} in the data folder:')

session_list = {}
for mouse in mice_list:
    mouse_folder = os.path.join(path_to_data_folder,mouse)
    session_list[mouse] = sorted([name for name in os.listdir(mouse_folder)
                           if os.path.isdir(os.path.join(mouse_folder, name))
                           and name.startswith('MOU')])
    nb_sessions = len(session_list[mouse])
    print(f'Hello, I\'m {mouse}! I have foraged for {nb_sessions} sessions:')
    print(session_list[mouse], '\n')
# Out:
# Found 30 mice in the data folder: MOU3974, MOU3975, MOU3987, MOU3988, MOU3991, MOU3992, MOU4122, MOU4123, MOU4124, MOU4172, MOU4175, MOU4183, MOU4185, MOU4186, MOU4192, MOU4551, MOU4552, MOU4560, MOU4561, MOU4562, MOU4563, MOU4623, MOU4624, MOU4692, MOU4694, MOU4695, MOU4696, MOU4698, MOU4703, MOU4704
def compute_average_direction(points):
    diffs = np.diff(points, axis=0)
    avg_diff = np.mean(diffs, axis=0)
    angle = np.arctan2(avg_diff[1], avg_diff[0])
    return avg_diff, angle

# %%
def detect_run_epochs(speeds, time_video_frames):
    """
    
    Identifies continuous epochs during which the mouse is moving above a certain speed (cut_off_speed).
    A minimal duration of low speed is necessary to be considered as the end of a run.
    Similarly, a minimal duration of high speed is necessary to be considered as a run.
    """
    
    #for this we need some parameters to cut the trajectory into run based on speed, duration of runs and pauses
    pause_min_duration = 0.1 #if a stop is shorter than this, merges the two epochs bordering it
    run_min_duration = 0.3 #minimal duration of an epoch to be considerd
    cut_off_speed = 7 # this value is the speed in cm/s. It is used to detect when the animals stop running. 
    
    
    
    run_epochs = []
    is_in_epoch = False  # Flag to track if we are currently in a running epoch
    epoch_start_index = 0

    if len(speeds) != len(time_video_frames):
        raise ValueError("speeds and time_video_frames have different lengths")

    for i in range(len(speeds)):
        if speeds[i] >= cut_off_speed:  # Speed above cut-off value
            if not is_in_epoch: # if the previous trajectory speed was not part of running epoch then this will be a start of a new epoch
                epoch_start_index = i  # Mark the beginning of a new epoch
                is_in_epoch = True
        else: # the speed of the current data point is below the treshold
            if is_in_epoch: # if we were in a run epoch just before (1st point below the treshold)
                # Check first if the pause between this epoch's starting point (time_video_frames[epoch_start_index]) and  
                # the previous epoch' last point time_video_frames[run_epochs[-1][1]] is shorter than the minimal time for a pause
                # then the previous epoch  should be extended to the previous data point.  
                if run_epochs and (time_video_frames[epoch_start_index] - time_video_frames[run_epochs[-1][1]] < pause_min_duration):
                    run_epochs[-1][1] = i - 1  # Extend the previous epoch
                else: # the pause has been long enough then we terminate the run epoch  other previous 
                    run_epochs.append([epoch_start_index, i - 1])  # Add new epoch
                is_in_epoch = False

    # Final check for any epoch still in progress
    if is_in_epoch:
        if run_epochs and (time_video_frames[epoch_start_index] - time_video_frames[run_epochs[-1][1]] < pause_min_duration):
            run_epochs[-1][1] = len(speeds) - 1
        elif (time_video_frames[-1] - time_video_frames[epoch_start_index]) >= run_min_duration:
            run_epochs.append([epoch_start_index, len(speeds) - 1])

    # Remove epochs that are too short
    run_epochs = [epoch for epoch in run_epochs if (time_video_frames[epoch[1]] - time_video_frames[epoch[0]]) >= run_min_duration]
    
    # Adjust the start and end of each epoch based on acceleration. The idea is that with the threshold method we miss the beginning and enf of the run
    # for the starting point. We are going back and find the point at wich the animal acceleration is less than 40% 
    # than the acceleration at the moment at which he passed the treshold. 
    clean_run_epochs = [None] * len(run_epochs)
    for index,epoch in enumerate(run_epochs):
        clean_run_epochs[index] = epoch.copy()
        epoch_start, epoch_end = epoch[0], epoch[1]
        # Adjust the start of the epoch
        current_point = epoch_start
        acceleration_at_crossing=(speeds[current_point + 1] - speeds[current_point]) / (time_video_frames[current_point + 1] - time_video_frames[current_point])
        while current_point > 0:
            previous_acceleration = (speeds[current_point] - speeds[current_point - 1]) / (time_video_frames[current_point] - time_video_frames[current_point - 1])
            if previous_acceleration <= (0.1 * acceleration_at_crossing) or previous_acceleration <= 0:
                break
            current_point -= 1
            #print(f'it went backward on epoch {index}')
        clean_run_epochs[index][0] = current_point

    #Adjust the end of the epoch
    #We are going forward after the speed crossed downward the speed threshold and find the point at wich the animal acceleration is less than 40% 
    #than the acceleration at the moment at which it passed the treshold. 
        current_point = epoch_end
        acceleration_at_crossing=(speeds[current_point - 1] - speeds[current_point]) / (time_video_frames[current_point] - time_video_frames[current_point-1])
        while current_point < len(speeds) - 1:
            next_acceleration = (speeds[current_point] - speeds[current_point + 1]) / (time_video_frames[current_point+1] - time_video_frames[current_point])
            if next_acceleration <= (0.1 * acceleration_at_crossing) or next_acceleration <= 0:
                break
            current_point += 1
            #print(f'it went forward on epoch {index}')
        clean_run_epochs[index][1] = current_point

    
   
    return run_epochs, clean_run_epochs

# %%
def find_run_type(run_epoch, folder_path_mouse_to_process, session_to_process):

    # Define the pickle file path
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)
    
    # Load the pickle file
    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    
    run_around_tower_ids = np.array([item[0] for item in session_data['all_epochs']['run_around_tower']])
    run_between_towers_ids = np.array([item[0] for item in session_data['all_epochs']['run_between_towers']])
    exploratory_run_ids = np.array([item[0] for item in session_data['all_epochs']['exploratory_run']])
    run_toward_tower_ids = np.array([item[0] for item in session_data['all_epochs']['run_toward_tower']])
    #print(immobility_ids)
    immobility_ids = np.array([[item[0],item[1]] for item in session_data['all_epochs']['immobility']])
    
    # condition_1 = np.logical_and(run_around_tower_ids[0][:]<=run_epoch[0],run_around_tower_ids[1][:]>run_epoch[1])
    # condition_2 = np.logical_and(run_between_towers_ids[0][:]<=run_epoch[0],run_between_towers_ids[1][:]>run_epoch[1])
    # condition_3 = np.logical_and(run_toward_tower_ids[0][:]<=run_epoch[0],run_toward_tower_ids[1][:]>run_epoch[1])
    # condition_4 = np.logical_and(exploratory_run_ids[0][:]<=run_epoch[0],exploratory_run_ids[1][:]>run_epoch[1])
    # condition_5 = np.logical_and(immobility_ids[0][:]<=run_epoch[0],immobility_ids[1][:]>run_epoch[1])
    
    condition_1 = run_epoch in run_around_tower_ids
    condition_2 = run_epoch in run_between_towers_ids
    condition_3 = run_epoch in run_toward_tower_ids
    condition_4 = run_epoch in exploratory_run_ids
    condition_5 = run_epoch in immobility_ids
    

    if np.any(condition_1):
    
        epoch_type = "run_around_tower"
        
    elif np.any(condition_2):
    
        epoch_type = "run_between_towers"

    elif np.any(condition_3):
    
        epoch_type = "run_toward_tower"    

    elif np.any(condition_4):
    
        epoch_type = "exploratory_run"

    elif np.any(condition_5):
    
        epoch_type = "immobility"    

    else:
        
        print("WARNING: unclassified epoch")
        epoch_type = "unclassified"

    #print(f"Epoch type found for epoch: {run_epoch}")


    return epoch_type

# %%
def plot_selected_run_epochs(folder_path_mouse_to_process, session_to_process, first_epoch_to_plot, last_epoch_to_plot, ax, points_for_direction=4, show_legend=True):
    
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    traj_df, turns_df, param_df=load_data(folder_path_mouse_to_process,session_to_process)

    traject_time = session_data['timeofframes']

    """if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]
    """
    speeds = session_data['speeds']

    smoothed_positions = session_data['positions']
    smoothed_Xpositions = smoothed_positions[0]
    smoothed_Ypositions = smoothed_positions[1]

    all_trapezes_coordinates_cm = session_data['all_trapezes_coordinates_cm']

    run_epochs, clean_run_epochs = detect_run_epochs(speeds,traject_time)

    run_types = ["run_around_tower", "run_between_towers", "run_toward_tower", "exploratory_run","immobility","unclassified"]
    type_names = ["Run around tower", "Run between towers", "Run toward tower", "Exploratory run","Immobility","Unclassified"]

    #cmap = plt.get_cmap('viridis')
    #colors = cmap(np.linspace(0.2, 1, len(run_types))) 
    colors = ["mediumslateblue", "green", "orange", "red", "yellow", "black"]
    
    trapeze_switch_times=[]
    #ax.figure(figsize=(10, 8))
    all_start_end_indexes=[]

    labels_displayed = set()

    for idx in range(first_epoch_to_plot, last_epoch_to_plot):
        
        run_epoch = clean_run_epochs[idx]
        start_index, end_index = run_epoch[0], run_epoch[1]
        #print(start_index,end_index)
        all_start_end_indexes.extend([start_index,end_index])
        #print(all_start_end_indexes)

        # Check if the indexes are within the bounds of traj_df
        if start_index < 0 or end_index >= len(traject_time):
            print(f"Indexes out of bounds for run_epoch: {run_epoch}")
            continue

        # Extract the run_epoch segment        
        run_epoch = [smoothed_Xpositions[start_index: end_index+1],smoothed_Ypositions[start_index: end_index+1]]
        times_run_epoch=traject_time[start_index: end_index+1]
        
        # Plot the raw trajectory of this epoch 
        #ax.plot(run_epoch[0], run_epoch[1], linestyle='--', color='c')
        # Plot the smooth trajectory of this epoch 

        epoch_type = find_run_type([start_index,end_index], folder_path_mouse_to_process, session_to_process)

        color = colors[run_types.index(epoch_type)]
        
        if not(color in labels_displayed):

                line_label = type_names[run_types.index(epoch_type)]
                labels_displayed.add(color)

        else:

            line_label = ''

        ax.plot(smoothed_Xpositions[start_index: end_index+1],smoothed_Ypositions[start_index: end_index+1], color=color, linestyle='-', label=line_label)


        # Mark the beginning of the trajectory
        ax.plot(run_epoch[0][0], run_epoch[1][0], 
                 marker='o', color='black', markersize=2)

        # Draw an arrow at the end of the trajectory
        if idx+1 == last_epoch_to_plot:
            
            dx = smoothed_Xpositions[end_index+1] - smoothed_Xpositions[end_index+1-points_for_direction]
            dy = smoothed_Ypositions[end_index+1] - smoothed_Ypositions[end_index+1-points_for_direction]
            norm_speed = np.hypot(dx, dy)
            if norm_speed != 0:
                dx /= norm_speed
                dy /= norm_speed
            ax.arrow(smoothed_Xpositions[end_index+1], smoothed_Ypositions[end_index+1], dx, dy,
                                    head_width=2, head_length=2, fc='red', ec='red', zorder=100)        

        """ax.arrow(
            run_epoch[0][-2], run_epoch[1][-2], 
            avg_diff[0], avg_diff[1],
            shape='full', lw=0, length_includes_head=True, head_width=2, color='r',
            label='End' if idx == first_epoch_to_plot else "", zorder=5
        )"""

        # Annotate the number of the quarter turn next to its starting point
        # ax.text(run_epoch[0][0], run_epoch[1][0], f'{idx + 1}', fontsize=8, color='black', ha='right')

        # Find turn in the turns_df data frame within this quarter turn based on time
        turns_in_QT = turns_df[(turns_df['time'] >= times_run_epoch[0]) & (turns_df['time'] <= times_run_epoch[-1])]
        #print(turns_in_QT)
        trapeze_switch_times.extend(turns_in_QT['time'].values)
        # Plot the switch of trapez as a cross marker on the trajectory
        #ax.scatter(turns_in_QT['xposition']*conversion_factor, (video_resolution[1]-turns_in_QT['yposition'])*conversion_factor, marker='x', color='m', label='Turn Positions')

        # Add labels to turns indicating arrivalTrapeze, departureTrapeze, and currentPatchTower
        # for _, turn in turns_in_QT.iterrows():
        #     ax.text(turn['xposition']*conversion_factor, (video_resolution[1]-turn['yposition'])*conversion_factor, f"{turn['currentPatch']}\n{turn['previousTrapeze']}\n{turn['currentTrapeze']}",
        #              fontsize=8, color='black', ha='center', va='bottom')

       # Generate a color map using matplotlib's tab10 colormap (which has 10 distinct colors) to plot the trapezes
    colors = list(mcolors.TABLEAU_COLORS.values())  # Using Tableau colors for distinct colors
    
    # Plot each square and trapeze with the same color for each tower
    # for i, (tower, trapezes) in enumerate(all_trapezes_coordinates_cm.items()):
    #     tower_color = colors[i % len(colors)]  # Cycle through the colors if there are more than 10 towers
    #     for trapeze, coordinates in trapezes.items():
    #         # Make a copy of the coordinates and close the polygon by appending the first vertex
    #         coordinates_copy = coordinates + [coordinates[0]]
    #         # Extract x and y coordinates for plotting
    #         x_coords, y_coords = zip(*coordinates_copy)
    #         ax.plot(x_coords, y_coords, label=f'{tower}_{trapeze}', color=tower_color,linestyle='--')

    # Plot the trapezes with varying border and fill colors
    
    #border_colors = ['black'] * 4
    fill_colors = ['lightblue'] * 4
    
    for i, (tower, trapezes) in enumerate(all_trapezes_coordinates_cm.items()):
        for j, (trapeze, coordinates) in enumerate(trapezes.items()):
            # Close the polygon by appending the first vertex
            coordinates_copy = coordinates + [coordinates[0]]
            x_coords, y_coords = zip(*coordinates_copy)
            
            # Fill the trapezes if requested
            ax.fill(x_coords, y_coords, color=fill_colors[j % len(fill_colors)], alpha=0.5)
            
            # Plot trapeze borders if requested
            #ax.plot(x_coords, y_coords, color=border_colors[j % len(border_colors)], linestyle='--')

    # Set plot limits and labels
  
    for spine in ax.spines.values():
        spine.set_visible(False)

    ax.set_xticks([])
    ax.set_yticks([])

    if show_legend:

        ax.legend(loc=[0.25,-0.2], frameon=False, fontsize=4)

    #ax.set_title(f'Selected Quarter Turns: QT {first_epoch_to_plot + 1} to QT {last_epoch_to_plot}')
    #plt.legend()
    #plt.gca().invert_yaxis()  # Invert the y-axis
    
    return all_start_end_indexes[0], all_start_end_indexes[-1],trapeze_switch_times

# %%
def plot_trajectory_speed_chunk(start_idx, end_idx, traject_time, speeds, run_epochs, clean_run_epochs, ax, folder_path_mouse_to_process, session_to_process, cut_off_speed=7,events_list=None):

    # Second subplot: Trajectory Speeds
    ax.plot(traject_time[start_idx:end_idx], speeds[start_idx:end_idx], label='Trajectory Speeds', color='black', marker='o', markerfacecolor='none', markersize=0.5, linewidth=0.5, zorder=11)
    
    # Mark the first and last points with different symbols and colors
    #ax.scatter(traject_time[start_idx], speeds[start_idx], color='green', marker='o', s=10, label='Start Point', zorder=10)
    #ax.scatter(traject_time[end_idx - 1], speeds[end_idx - 1], color='red', marker='o',s=10, label='End Point')
    
    ax.axhline(y=cut_off_speed, color='orange', linestyle='--', label='Cut-off Speed')
    
    run_types = ["run_around_tower","run_between_towers", "run_toward_tower", "exploratory_run","immobility","unclassified"]
    #cmap = plt.get_cmap('viridis')
    #colors = cmap(np.linspace(0.2, 1, len(run_types))) 
    colors = ["blue","green", "orange", "red", "yellow", "black"]

    # Plot original run epochs on the first subplot
    
    
    # for idx, epoch in enumerate(run_epochs):
    #     epoch_start, epoch_end = epoch[0], epoch[1]
        
    #     if epoch_start >= start_idx and epoch_end <= end_idx:
    #         epoch_type = find_run_type(epoch, folder_path_mouse_to_process, session_to_process)
    #         color = colors[run_types.index(epoch_type)]
    #         ax.axvspan(traject_time[epoch_start], traject_time[epoch_end], color=color, alpha=0.3, linewidth=0, label='Original Run Epoch' if idx == 0 else "", zorder=1)
        
    #     #     ax.axvspan(traject_time[epoch_start], traject_time[epoch_end], color='red', alpha=0.3, linewidth=0, label='Original Run Epoch' if idx == 0 else "")

    #     #    ax.axvspan(traject_time[epoch_start], traject_time[epoch_end], color="red", alpha=0.3, linewidth=0, label='Original Run Epoch' if idx == 0 else "")
    #     #    

    # Plot adjusted run epochs on the first subplot
    for idx, clean_epoch in enumerate(clean_run_epochs):
        
        epoch = run_epochs[idx]

        clean_epoch_start, clean_epoch_end = clean_epoch[0], clean_epoch[1]
        epoch_start, epoch_end = epoch[0], epoch[1]
        

        if clean_epoch_start >= start_idx and clean_epoch_end <= end_idx:
 

            clean_epoch_type = find_run_type(clean_epoch, folder_path_mouse_to_process, session_to_process)

            color = colors[run_types.index(clean_epoch_type)]
            ax.axvspan(traject_time[clean_epoch_start], traject_time[clean_epoch_end], color=color, alpha=0.3, linewidth=0, label='Adjusted Run Epoch' if idx == 0 else "", zorder=2)
            ax.axvspan(traject_time[epoch_start], traject_time[epoch_end], color=color, alpha=0.3, linewidth=0, label='Original Run Epoch' if idx == 0 else "", zorder=1)

        #     ax.axvspan(traject_time[epoch_start], traject_time[epoch_end], color='green', alpha=0.3, linewidth=0, label='Adjusted Run Epoch' if idx == 0 else "")
        #    ax.axvspan(traject_time[epoch_start], traject_time[epoch_end], color="green", alpha=0.3, linewidth=0, label='Adjusted Run Epoch' if idx == 0 else "")
          
    
    
    # Plot optional events on the first subplot
    # if events_list is not None:
    #     for event in events_list:
    #         event_index = np.where(traject_time == event)[0]
    #         if event_index.size > 0:  # Check if the event exists in the time array
    #             ax.axvline(x=traject_time[event_index[0]], color='magenta', linestyle='--', label='Event', linewidth=0)
    
    ax.set_ylim(bottom=-5, top=max(speeds[start_idx:end_idx])*1.1)
    ax.set_xlabel('Time (s)',fontsize=5)
    ax.set_ylabel('Speed (cm/s)',fontsize=5)
    #ax.set_title('Trajectory Speeds with Run Epochs Highlighted')
    #ax.legend()

# %%
def plot_learning_curves(mouse_data_persession, mice_list=None, mice_to_highlight=[], axs=None, session_limit=None, show_xlabel = True, ylabel='Distance Ran', tick_interval=1, xlim=None, ylim=None, show_legend=True):
    #plt.figure(figsize=(12, 6))

    # If no mice are specified, use all available mice
    if mice_list is None:
        mice_list = list(mouse_data_persession.keys())

    all_session_indices = set()  # Track all session indices across selected mice
    values_per_session = {}   # Store values for each session across mice

    # Loop through each mouse and gather data
    for mouse in mice_list:

        if mouse not in mouse_data_persession:
            print(f"Mouse {mouse} not found in data. Skipping.")
            continue    

        if session_limit == None:

            session_limit = len(mouse_data_persession[mouse])


        sessions = mouse_data_persession[mouse][:session_limit]
        
        # Extract session indices and values
        session_indices = [session[0] for session in sessions]
        values = [session[1] for session in sessions]

        # Plot individual mouse curves
        
        # if not(mouse in mice_to_highlight):
        
        #     axs.plot(session_indices, values, marker='o', linewidth=0.5, markersize=1, alpha = 0.3, markeredgewidth=0.0)

        if mouse == mice_to_highlight[0]:

            axs.plot(session_indices, values, color="darkorange", marker='o', linewidth=0.5, markersize=1, label=f"Mouse {mice_to_highlight.index(mouse)+1}", zorder=100)
        
        elif mouse == mice_to_highlight[1]:

            axs.plot(session_indices, values, color="green", marker='o', linewidth=0.5, markersize=1, label=f"Mouse {mice_to_highlight.index(mouse)+1}", zorder=100)

        # if mouse in mice_to_highlight:
        
        #     axs.plot(session_indices, values, marker='o', linewidth=1, markersize=1, label=f"Mouse {mice_to_highlight.index(mouse)+1}", zorder=100)

        # else:

        #     axs.plot(session_indices, values, marker='o', linewidth=0.5, markersize=1, alpha = 0.3, markeredgewidth=0.0)
        
        # Update all_session_indices and values_per_session
        all_session_indices.update(session_indices)
        for session, value in sessions:
            if session not in values_per_session:
                values_per_session[session] = []
            values_per_session[session].append(value)

    # Convert session indices to a sorted list
    sorted_sessions = sorted(all_session_indices)

    # Calculate median and percentiles (25th and 75th) for each session
    median_values = []
    lower_quartile = []
    upper_quartile = []

    for session in sorted_sessions:
        session_values = values_per_session[session]
        median_values.append(np.median(session_values))
        lower_quartile.append(np.percentile(session_values, 25))
        upper_quartile.append(np.percentile(session_values, 75))

    median_values = np.array(median_values)
    lower_quartile = np.array(lower_quartile)
    upper_quartile = np.array(upper_quartile)

    # Plot median as a thick black line
    #axs.plot(sorted_sessions, median_values, color='black', linewidth=1, label='Median')
    axs.plot(sorted_sessions, median_values, alpha=1, color='black', linewidth = 2, label='Median', zorder=50)
    axs.fill_between(sorted_sessions, lower_quartile, upper_quartile, alpha=0.2, label='25th-75th Percentile')

    # Plot the 25th to 75th percentile range as a shaded area
    #axs.fill_between(sorted_sessions, lower_quartile, upper_quartile, color='lightgray', alpha=1, label='25th-75th Percentile')

    # Set plot labels, title, and grid
    if show_xlabel:
        axs.set_xlabel('Session Number', fontsize=5)
    
    axs.set_ylabel(ylabel, fontsize=5)
    #plt.title(title)
    
    # Ensure x-axis labels are integers and start from 1
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
    
    # Set x-ticks with custom spacing
    if all_session_indices:
        max_index = max(all_session_indices)
        axs.set_xticks(range(1, max_index + 1, tick_interval))

    # Set y-axis limits if specified
    if xlim is not None:
        axs.set_xlim(xlim)
    
    # Set y-axis limits if specified
    if ylim is not None:
        axs.set_ylim(ylim)

    if show_legend:
    
        axs.legend(frameon=False, fontsize=4, loc=(0.05,0.7))
    
    #legend = axs.legend()
    #legend.get_frame().set_facecolor('white')
    

    #plt.show()

# %%
def plot_maze_towers_with_results(vertices, color, results, ax, linewidth=0.1):
    """
    Plots the edges of a tower or trapeze based on given vertices, 
    and adds behavior data as text inside the plotted shape.
    
    Parameters:
        vertices (list of tuples): List of (x, y) coordinates for the corners of the tower/trapeze.
        color (str): Color code for the plot (e.g., 'r' for red).
        results (dict): Dictionary containing behavioral data with keys 'rewarded_CW', 'total_CW', 
                        'rewarded_CCW', and 'total_CCW'.
        
    """
    # Close the polygon by appending the first vertex to the end
    closed_vertices = vertices + [vertices[0]]
    closed_vertices = list(zip(*closed_vertices))  # Transpose vertices for plotting (x, y)

    # Plot the tower/trapeze if the flag is True
    
    ax.plot(closed_vertices[0], closed_vertices[1], color,linewidth=linewidth)
    
    # Calculate the center of the polygon for labeling
    center_x = sum(v[0] for v in vertices) / len(vertices)
    center_y = sum(v[1] for v in vertices) / len(vertices)

    # Add behavior data as text inside the polygon
    behavior_text = (f"Rewarded/Total\n"
                     f"CW: {results['rewarded_CW']}/{results['total_CW']}\n"
                     f"CCW: {results['rewarded_CCW']}/{results['total_CCW']}")
    
    #ax.text(center_x, center_y, behavior_text, fontsize=7, ha='center', va='center', color='black')

# %%
"""def finding_tower_rewarded_direction(folder_path_mouse_to_analyse, session_to_analyse, time_video_frames, frames_of_turn):

# Looking for the rewarded direction FOR ALL THE SESSIONS

    # sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
    #                               if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
    #                               and name.startswith('MOU')])

    #output_pickle_filename = f"{sessions_to_analyse[-1]}_basic_analysing_output.pickle"
    #output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, sessions_to_analyse[-1], output_pickle_filename)

    #with open(output_pickle_filepath, 'rb') as file:
    #        session_data = pickle.load(file)

    # session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,sessions_to_analyse[-1])

    session_traj_df, session_turns_df, session_param_df = load_data(folder_path_mouse_to_analyse,session_to_analyse)

    run_start_index = frames_of_turn[0]
    run_end_index = frames_of_turn[1]
    start_stop_times_run_epoch = [time_video_frames[run_start_index], time_video_frames[run_end_index]]
        
    # Find the relevant entries in turns_df within the run epoch
    condition = (session_turns_df['time'] >= start_stop_times_run_epoch[0]) & (session_turns_df['time'] <= start_stop_times_run_epoch[1])
    
    if not condition.any():
        print("ERROR: epoch start and/or end time do not exist")
        

    rewarded_direction_degrees = session_turns_df[condition]['Rewarded'].iat[0]
    
    rewarded_direction_degrees = rewarded_direction_degrees.replace('[','')

    rewarded_direction_degrees = rewarded_direction_degrees.replace(']','')

    rewarded_direction_degrees = float(rewarded_direction_degrees)

    if rewarded_direction_degrees == 270:

        rewarded_direction = 'CW'

    elif rewarded_direction_degrees == 90:
        
        rewarded_direction = 'CCW'
        
    # elif rewarded_direction_degrees == '[90, 270]':
    
    #     rewarded_direction = 'both'

    else:

        print(rewarded_direction_degrees)

        print('ERROR')

        return 
    
    return rewarded_direction
    
    #"""
# Out:
# 'def finding_tower_rewarded_direction(folder_path_mouse_to_analyse, session_to_analyse, time_video_frames, frames_of_turn):\n\n# Looking for the rewarded direction FOR ALL THE SESSIONS\n\n    # sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)\n    #                               if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))\n    #                               and name.startswith(\'MOU\')])\n\n    #output_pickle_filename = f"{sessions_to_analyse[-1]}_basic_analysing_output.pickle"\n    #output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, sessions_to_analyse[-1], output_pickle_filename)\n\n    #with open(output_pickle_filepath, \'rb\') as file:\n    #        session_data = pickle.load(file)\n\n    # session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,sessions_to_analyse[-1])\n\n    session_traj_df, session_turns_df, session_param_df = load_data(folder_path_mouse_to_analyse,session_to_analyse)\n\n    run_start_index = frames_of_turn[0]\n    run_end_index = frames_of_turn[1]\n    start_stop_times_run_epoch = [time_video_frames[run_start_index], time_video_frames[run_end_index]]\n        \n    # Find the relevant entries in turns_df within the run epoch\n    condition = (session_turns_df[\'time\'] >= start_stop_times_run_epoch[0]) & (session_turns_df[\'time\'] <= start_stop_times_run_epoch[1])\n    \n    if not condition.any():\n        print("ERROR: epoch start and/or end time do not exist")\n        \n\n    rewarded_direction_degrees = session_turns_df[condition][\'Rewarded\'].iat[0]\n    \n    rewarded_direction_degrees = rewarded_direction_degrees.replace(\'[\',\'\')\n\n    rewarded_direction_degrees = rewarded_direction_degrees.replace(\']\',\'\')\n\n    rewarded_direction_degrees = float(rewarded_direction_degrees)\n\n    if rewarded_direction_degrees == 270:\n\n        rewarded_direction = \'CW\'\n\n    elif rewarded_direction_degrees == 90:\n        \n        rewarded_direction = \'CCW\'\n        \n    # elif rewarded_direction_degrees == \'[90, 270]\':\n    \n    #     rewarded_direction = \'both\'\n\n    else:\n\n        print(rewarded_direction_degrees)\n\n        print(\'ERROR\')\n\n        return \n    \n    return rewarded_direction\n    \n    #'

# %%
def finding_tower_rewarded_direction(folder_path_mouse_to_analyse, session_to_analyse, time_video_frames, frames_of_turn):

# Looking for the rewarded direction FOR ALL THE SESSIONS

    # sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
    #                               if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
    #                               and name.startswith('MOU')])

    #output_pickle_filename = f"{sessions_to_analyse[-1]}_basic_analysing_output.pickle"
    #output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, sessions_to_analyse[-1], output_pickle_filename)

    #with open(output_pickle_filepath, 'rb') as file:
    #        session_data = pickle.load(file)

    # session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,sessions_to_analyse[-1])

    session_traj_df, session_turns_df, session_param_df = load_data(folder_path_mouse_to_analyse,session_to_analyse)

    run_start_index = frames_of_turn[0]
    run_end_index = frames_of_turn[1]
    start_stop_times_run_epoch = [time_video_frames[run_start_index], time_video_frames[run_end_index]]
        
    # Find the relevant entries in turns_df within the run epoch
    condition = (session_turns_df['time'] >= start_stop_times_run_epoch[0]) & (session_turns_df['time'] <= start_stop_times_run_epoch[1])
    
    if not condition.any():
        print("ERROR: epoch start and/or end time do not exist")
        

    rewarded_direction_degrees = session_turns_df[condition]['Rewarded'].iat[0]
    
    rewarded_direction_degrees = rewarded_direction_degrees.replace('[','')

    rewarded_direction_degrees = rewarded_direction_degrees.replace(']','')

    rewarded_direction_degrees = float(rewarded_direction_degrees)

    if rewarded_direction_degrees == 270:

        rewarded_direction = 'CW'

    elif rewarded_direction_degrees == 90:
        
        rewarded_direction = 'CCW'
        
    # elif rewarded_direction_degrees == '[90, 270]':
    
    #     rewarded_direction = 'both'

    else:

        print(rewarded_direction_degrees)

        print('ERROR')

        return 
    
    return rewarded_direction
    
    #

# %%
def plot_run_type(folder_path_mouse_to_process, session_to_process, ax, runtype='', q=4, time_start=None, time_end=None):
    
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    traject_time = session_data['timeofframes']

    if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]

    smoothed_positions = session_data['positions']
    smoothed_Xpositions = smoothed_positions[0]
    smoothed_Ypositions = smoothed_positions[1]

    all_epochs = session_data['all_epochs']

    all_trapezes_coordinates_cm = session_data['all_trapezes_coordinates_cm']


    if not runtype:
        warnings.warn("The 'runtype' parameter is required and was not provided.")
        return
    
    runtype_epochs = all_epochs.get(runtype)
    
    if runtype_epochs is None:
        warnings.warn(f"The 'runtype' '{runtype}' is not found in 'all_epochs'.")
        return
    
    #totaltime = 0
    #totaldistance = 0
    #meanspeed = []
    #maxspeed = []
    
    #distances, speeds = compute_distance_speed_angular_speed([smoothed_Xpositions, smoothed_Ypositions], traject_time)[0:2]
    
    # Plot each square and trapeze with the same color for each tower
    fill_colors = ['lightblue'] * 4
    
    for i, (tower, trapezes) in enumerate(all_trapezes_coordinates_cm.items()):
        for j, (trapeze, coordinates) in enumerate(trapezes.items()):
            # Close the polygon by appending the first vertex
            coordinates_copy = coordinates + [coordinates[0]]
            x_coords, y_coords = zip(*coordinates_copy)
            
            # Fill the trapezes if requested
            ax.fill(x_coords, y_coords, color=fill_colors[j % len(fill_colors)], alpha=0.5)
            
            # Plot trapeze borders if requested
            #ax.plot(x_coords, y_coords, color=border_colors[j % len(border_colors)], linestyle='--')
    
    # for tower, trapezes in all_trapezes_coordinates_cm.items():
        
    #     for trapeze, coordinates in trapezes.items():
    #         # Make a copy of the coordinates and close the polygon by appending the first vertex
    #         coordinates_copy = coordinates + [coordinates[0]]
    #         # Extract x and y coordinates for plotting
    #         x_coords, y_coords = zip(*coordinates_copy)
    #         ax.plot(x_coords, y_coords, label=f'{tower}_{trapeze}', color='gray',linestyle='--')

    for runtype_epoch in runtype_epochs:
        
        # if runtype=='run_around_tower':

        #     if runtype_epoch[3]['num_trapezeswitch'] > 1:
                
        #         continue
        
        start_index, end_index = runtype_epoch[0][0], runtype_epoch[0][1]

        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue
        
        # Check if the indexes are within the bounds of the arrays
        if start_index < 0 or end_index >= len(traject_time):
            print(f"Indexes out of bounds for runtype_epoch: {runtype_epoch}")
            continue

        # Extract the run epoch, compute duration, distance and speed
        runtype_epoch_Xpositions = smoothed_Xpositions[start_index:end_index + 1]
        runtype_epoch_Ypositions = smoothed_Ypositions[start_index:end_index + 1]
        #epochduration = traject_time[end_index] - traject_time[start_index]
        #totaltime += epochduration
        #distanceran = np.sum(distances[start_index:end_index])
        #totaldistance += distanceran
        #meanspeed.append(distanceran / epochduration)
        #maxspeed.append(np.max(speeds[start_index:end_index]))

        numberofpositions=len(runtype_epoch_Xpositions)
    #     colors = [(0, 1, 0), (1, 0.5, 0), (1, 0, 0)] # Green to orange to red
    #     cmap = LinearSegmentedColormap.from_list('custom_cmap', colors)
    # #    cmap = plt.get_cmap('plasma')
    #     colorgradientforthisrun = cmap(np.linspace(0, 1, numberofpositions)) 

        # Ensure both lists have the same length
        if len(runtype_epoch_Xpositions) != len(runtype_epoch_Ypositions):
            raise ValueError("The lengths of X and Y positions lists must be the same.")

        # Loop through the lists and obtain each pair of values with indices
        for index  in range(numberofpositions-2):

            if runtype=='run_around_tower':
                color = 'blue' if runtype_epoch[3]['direction'] == 'CW' else 'red'
            else:
                color = 'black'
            #ax.plot(runtype_epoch_Xpositions[index:index+2],runtype_epoch_Ypositions[index:index+2],color=colorgradientforthisrun[index], linewidth=0.5)
            ax.plot(runtype_epoch_Xpositions[index:index+2],runtype_epoch_Ypositions[index:index+2],color=color, linewidth=0.5)
        
        # Plot the trajectory
        #ax1.plot(runtype_epoch_Xpositions, runtype_epoch_Ypositions, linestyle='-', label=f"Traj {start_index}-{end_index}")
        
        # Plot the start and end points
        ax.plot(runtype_epoch_Xpositions[0], runtype_epoch_Ypositions[0], color='black', marker='o', markersize=1)  # Start point

        # Compute the direction of the arrow using the last q points
        if len(runtype_epoch_Xpositions) >= q:
            dx = runtype_epoch_Xpositions[-1] - runtype_epoch_Xpositions[-q]
            dy = runtype_epoch_Ypositions[-1] - runtype_epoch_Ypositions[-q]
            
            # Normalize the direction
            norm = np.hypot(dx, dy)
            if norm != 0:
                dx /= norm
                dy /= norm
            
            # Plot the arrow
            ax.arrow(runtype_epoch_Xpositions[-1], runtype_epoch_Ypositions[-1], dx, dy,
                      head_width=1, head_length=1, fc='red', ec='red')
        
    #print(np.median(maxspeed))

    for spine in ax.spines.values():
        spine.set_visible(False)

    ax.set_xticks([])
    ax.set_yticks([])
    #ax.set_title(f"{runtype} (Tot. Duration: {totaltime:.2f}s; Tot. Distance: {totaldistance:.2f}cm; Mean speed: {np.median(meanspeed):.2f}cm/s; Max speed: {np.median(maxspeed):.2f}cm/s)")

# %%
def plot_runs_around_speed_profiles(folder_path_mouse_to_process, session_to_process, ax, time_start=None, time_end=None, xlim=None, ylim=None, show_xlabel=True, show_ylabel=True, show_color_bar=True):

    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    #traj_df, turns_df, param_df=load_data(folder_path_mouse_to_process,session_to_process)

    traject_time = session_data['timeofframes']

    if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]

    # distances = session_data['distances']
    # speeds = session_data['speeds']
    # angular_speeds = session_data['angular_speeds']


    smoothed_positions = session_data['positions']
    smoothed_Xpositions = smoothed_positions[0]
    smoothed_Ypositions = smoothed_positions[1]
    speeds = session_data['speeds']

    runs_around_tower = copy.deepcopy(session_data['all_epochs']['run_around_tower'])


    n_total = 0

    for run_around_tower in runs_around_tower:

        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]
        
        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue

        n_total += 1

    timeANDmedian_speed_of_runs = []
    cmap = plt.cm.viridis
    norm = Normalize(vmin=0, vmax=n_total)

    local_index = 0

    for run_around_tower in runs_around_tower:

        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]

        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue

        runtype_epoch_Xpositions = smoothed_Xpositions[start_index:end_index + 1]
        runtype_epoch_Ypositions = smoothed_Ypositions[start_index:end_index + 1]

        if len(runtype_epoch_Xpositions) != len(runtype_epoch_Ypositions):
            raise ValueError("The lengths of X and Y positions lists must be the same.")

        adjusted_time = [t - traject_time[start_index] for t in traject_time[start_index:end_index + 1]]
        ax.plot(adjusted_time, speeds[start_index:end_index + 1], color=cmap(norm(local_index)))
        timeANDmedian_speed_of_runs.append([traject_time[start_index], np.median(speeds[start_index:end_index + 1]),np.max(speeds[start_index:end_index + 1])])

        local_index += 1 
    
    if show_xlabel:

        ax.set_xlabel('Time (s)', fontsize=5)
    
    if show_ylabel:
    
        ax.set_ylabel('Speed (cm/s)', fontsize=5)

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    # Create an additional axes for the colorbar
    if show_color_bar:
        cbax = ax.inset_axes([0.25, 0.8, 0.5, 0.07]) 
        cbar = fig.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=norm), cax=cbax, orientation='horizontal')
        cbar.set_label('Index of Run', fontsize=5)
        cbar.set_ticks([0, n_total])
        cbar.set_ticklabels(['First', 'Last'], fontsize=5)

# %%
def plot_runs_around_towers_origin(folder_path_mouse_to_process, session_to_process, ax, q=4, time_start=None, time_end=None, show_legend=True, xlim=None, ylim=None, show_xlabel=True, show_ylabel=True):
    
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    #traj_df, turns_df, param_df=load_data(folder_path_mouse_to_process,session_to_process)

    traject_time = session_data['timeofframes']

    if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]

    # distances = session_data['distances']
    # speeds = session_data['speeds']
    # angular_speeds = session_data['angular_speeds']


    smoothed_positions = session_data['positions']
    smoothed_Xpositions = smoothed_positions[0]
    smoothed_Ypositions = smoothed_positions[1]

    runs_around_tower = copy.deepcopy(session_data['all_epochs']['run_around_tower'])

    
    fixed_origin = (0, 0)  # Define a fixed origin point
    #cmap = plt.cm.viridis
    norm = Normalize(vmin=0, vmax=len(runs_around_tower))
    labels_displayed = set()
    
    for run_around_tower in runs_around_tower:
        
        # if run_around_tower[3]['num_trapezeswitch'] > 1:
        #     continue

        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]

        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue

        runtype_epoch_Xpositions = smoothed_Xpositions[start_index:end_index + 1]
        runtype_epoch_Ypositions = smoothed_Ypositions[start_index:end_index + 1]
        numberofpositions = len(runtype_epoch_Xpositions)
        
        colors = [(0, 1, 0), (1, 0.5, 0), (1, 0, 0)] # Green to orange to red
        cmap = LinearSegmentedColormap.from_list('custom_cmap', colors)
    #    cmap = plt.get_cmap('plasma')
        colorgradientforthisrun = cmap(np.linspace(0, 1, numberofpositions)) 
        #custom_cmap(numberofpositions)  # Generate color gradient for this run

        start_x, start_y = runtype_epoch_Xpositions[0], runtype_epoch_Ypositions[0]
        translated_Xpositions = [x - start_x + fixed_origin[0] for x in runtype_epoch_Xpositions]
        translated_Ypositions = [y - start_y + fixed_origin[1] for y in runtype_epoch_Ypositions]

        for i in range(numberofpositions - 1):

            color = 'blue' if run_around_tower[3]['direction'] == 'CW' else 'red'
            
            #ax.plot(translated_Xpositions[i:i+2], translated_Ypositions[i:i+2], color=colorgradientforthisrun[i], linewidth=0.5)
            

            if color == 'blue' and not('blue' in labels_displayed):

                line_label = 'CW turns'
                labels_displayed.add('blue')
                
            elif color == 'red' and not('red' in labels_displayed):

                line_label = 'CCW turns'
                labels_displayed.add('red')

            else:

                line_label = ''
            
            ax.plot(translated_Xpositions[i:i+2], translated_Ypositions[i:i+2], color=color, linewidth=0.5, label=line_label)

        ax.plot(translated_Xpositions[0], translated_Ypositions[0], marker='o', color='black', linewidth=0.5, markersize=1)                                                                                                                             

        if len(translated_Xpositions) >= q:
            dx = translated_Xpositions[-1] - translated_Xpositions[-q]
            dy = translated_Ypositions[-1] - translated_Ypositions[-q]
            norm_speed = np.hypot(dx, dy)
            if norm_speed != 0:
                dx /= norm_speed
                dy /= norm_speed
            ax.arrow(translated_Xpositions[-1], translated_Ypositions[-1], dx, dy,
                                       head_width=1, head_length=1, fc='black', ec='black')

    if show_xlabel:
        
        ax.set_xlabel('X Position (cm)')
    
    if show_ylabel:
        
        ax.set_ylabel('Y Position (cm)')

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    if show_legend:
        ax.legend(loc=[0.4,1.2],frameon=False, fontsize=4)

    # if show_color_bar:
    #     cbax = ax.inset_axes([0.25, 1.2, 0.5, 0.05])         
    #     cbar = fig.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=norm), cax=cbax, orientation='horizontal')
    #     cbar.set_label('Timeline of run', fontsize=5)
    #     cbar.set_ticks([0, len(runs_around_tower)])
    #     cbar.set_ticklabels(['Start', 'End'], fontsize=5)

# %%
"""def plot_cumulated_turns_time_profile(folder_path_mouse_to_process, session_to_process, ax, time_start=None, time_end=None, xlim=None, ylim=None, show_xlabel=True, show_ylabel=True, show_legend=True):

    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    traject_time = session_data['timeofframes']

    if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]

    #selected_frames = np.where(np.logical_and(traject_time>=time_start, traject_time<=time_end))[0] 
    
    #traject_time = traject_time[selected_frames]

    # smoothed_positions = session_data['positions']
    # smoothed_Xpositions = smoothed_positions[0]#[selected_frames]
    # smoothed_Ypositions = smoothed_positions[1]#[selected_frames]

    runs_around_tower = copy.deepcopy(session_data['all_epochs']['run_around_tower'])
    #runs_around_tower = []

    # for run_around_tower in session_data['all_epochs']['run_around_tower']:

    #     if run_around_tower[0][0] in selected_frames and run_around_tower[0][1] in selected_frames:
    #         runs_around_tower.append(run_around_tower)

    runs_around_tower_to_keep = []

    time_of_runsaroundtower_good = []
    time_of_runsaroundtower_bad = []

    for run_around_tower in runs_around_tower:
        
        # if run_around_tower[3]['num_trapezeswitch'] > 1:
        #     continue

        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]

        rewarded_direction = finding_tower_rewarded_direction(folder_path_mouse_to_process, session_to_process, time_video_frames=traject_time, frames_of_turn=[start_index, end_index])

        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue
        
        if run_around_tower[3]['direction'] == rewarded_direction:
        
            time_of_runsaroundtower_good.append(run_around_tower[4]['epoch_time'])

        else:

            time_of_runsaroundtower_bad.append(run_around_tower[4]['epoch_time'])


        runs_around_tower_to_keep.append(run_around_tower)
        



    good_turns_time = np.sort(time_of_runsaroundtower_good)
    bad_turns_time = np.sort(time_of_runsaroundtower_bad)

    cumulated_good_turns = np.arange(1, len(good_turns_time) + 1)
    cumulated_bad_turns = np.arange(1, len(bad_turns_time) + 1)

    
    # if rewarded_direction == 'CW': #'[270]':

    #     good_turns_time = CW_times_sorted
    #     bad_turns_time = CCW_times_sorted

    #     cumulated_good_turns = CW_cumulative
    #     cumulated_bad_turns = CCW_cumulative

    # elif rewarded_direction == 'CCW': #'[90]':
        
    #     good_turns_time = CCW_times_sorted
    #     bad_turns_time = CW_times_sorted
        
    #     cumulated_good_turns = CCW_cumulative
    #     cumulated_bad_turns = CW_cumulative
        
    # else:

    #     print('ERROR')

    #     return 
    
    ax.step(good_turns_time, cumulated_good_turns, where='post', label='Rewarded direction', color='violet')
    ax.step(bad_turns_time, cumulated_bad_turns, where='post', label='Unrewarded direction', color='indigo')
    
    if show_xlabel:
        ax.set_xlabel('Time of turn (s)', fontsize=5)
    if show_ylabel:
        ax.set_ylabel('Cumulative number of turns', fontsize=5)

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    
    #ax.set_title('Cumulative Dynamics of CW vs. CCW Runs')
    
    if show_legend:
        ax.legend(frameon=False, fontsize=4)
    
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    """
# Out:
# 'def plot_cumulated_turns_time_profile(folder_path_mouse_to_process, session_to_process, ax, time_start=None, time_end=None, xlim=None, ylim=None, show_xlabel=True, show_ylabel=True, show_legend=True):\n\n    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        \n    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)\n\n    with open(output_pickle_filepath, \'rb\') as file:\n        session_data = pickle.load(file)\n\n    traject_time = session_data[\'timeofframes\']\n\n    if time_start is None:\n        time_start = traject_time[0]\n    if time_end is None:\n        time_end = traject_time[-1]\n\n    #selected_frames = np.where(np.logical_and(traject_time>=time_start, traject_time<=time_end))[0] \n    \n    #traject_time = traject_time[selected_frames]\n\n    # smoothed_positions = session_data[\'positions\']\n    # smoothed_Xpositions = smoothed_positions[0]#[selected_frames]\n    # smoothed_Ypositions = smoothed_positions[1]#[selected_frames]\n\n    runs_around_tower = copy.deepcopy(session_data[\'all_epochs\'][\'run_around_tower\'])\n    #runs_around_tower = []\n\n    # for run_around_tower in session_data[\'all_epochs\'][\'run_around_tower\']:\n\n    #     if run_around_tower[0][0] in selected_frames and run_around_tower[0][1] in selected_frames:\n    #         runs_around_tower.append(run_around_tower)\n\n    runs_around_tower_to_keep = []\n\n    time_of_runsaroundtower_good = []\n    time_of_runsaroundtower_bad = []\n\n    for run_around_tower in runs_around_tower:\n        \n        # if run_around_tower[3][\'num_trapezeswitch\'] > 1:\n        #     continue\n\n        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]\n\n        rewarded_direction = finding_tower_rewarded_direction(folder_path_mouse_to_process, session_to_process, time_video_frames=traject_time, frames_of_turn=[start_index, end_index])\n\n        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:\n        \n            continue\n        \n        if run_around_tower[3][\'direction\'] == rewarded_direction:\n        \n            time_of_runsaroundtower_good.append(run_around_tower[4][\'epoch_time\'])\n\n        else:\n\n            time_of_runsaroundtower_bad.append(run_around_tower[4][\'epoch_time\'])\n\n\n        runs_around_tower_to_keep.append(run_around_tower)\n        \n\n\n\n    good_turns_time = np.sort(time_of_runsaroundtower_good)\n    bad_turns_time = np.sort(time_of_runsaroundtower_bad)\n\n    cumulated_good_turns = np.arange(1, len(good_turns_time) + 1)\n    cumulated_bad_turns = np.arange(1, len(bad_turns_time) + 1)\n\n    \n    # if rewarded_direction == \'CW\': #\'[270]\':\n\n    #     good_turns_time = CW_times_sorted\n    #     bad_turns_time = CCW_times_sorted\n\n    #     cumulated_good_turns = CW_cumulative\n    #     cumulated_bad_turns = CCW_cumulative\n\n    # elif rewarded_direction == \'CCW\': #\'[90]\':\n        \n    #     good_turns_time = CCW_times_sorted\n    #     bad_turns_time = CW_times_sorted\n        \n    #     cumulated_good_turns = CCW_cumulative\n    #     cumulated_bad_turns = CW_cumulative\n        \n    # else:\n\n    #     print(\'ERROR\')\n\n    #     return \n    \n    ax.step(good_turns_time, cumulated_good_turns, where=\'post\', label=\'Rewarded direction\', color=\'violet\')\n    ax.step(bad_turns_time, cumulated_bad_turns, where=\'post\', label=\'Unrewarded direction\', color=\'indigo\')\n    \n    if show_xlabel:\n        ax.set_xlabel(\'Time of turn (s)\', fontsize=5)\n    if show_ylabel:\n        ax.set_ylabel(\'Cumulative number of turns\', fontsize=5)\n\n    ax.set_xlim(xlim)\n    ax.set_ylim(ylim)\n    \n    #ax.set_title(\'Cumulative Dynamics of CW vs. CCW Runs\')\n    \n    if show_legend:\n        ax.legend(frameon=False, fontsize=4)\n    \n    ax.spines[\'right\'].set_visible(False)\n    ax.spines[\'top\'].set_visible(False)\n    '

# %%
def plot_cumulated_turns_time_profile(folder_path_mouse_to_process, session_to_process, ax, time_start=None, time_end=None, xlim=None, ylim=None, show_xlabel=True, show_ylabel=True, show_legend=True):

    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    traject_time = session_data['timeofframes']

    if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]

    #selected_frames = np.where(np.logical_and(traject_time>=time_start, traject_time<=time_end))[0] 
    
    #traject_time = traject_time[selected_frames]

    # smoothed_positions = session_data['positions']
    # smoothed_Xpositions = smoothed_positions[0]#[selected_frames]
    # smoothed_Ypositions = smoothed_positions[1]#[selected_frames]

    runs_around_tower = copy.deepcopy(session_data['all_epochs']['run_around_tower'])
    #runs_around_tower = []

    # for run_around_tower in session_data['all_epochs']['run_around_tower']:

    #     if run_around_tower[0][0] in selected_frames and run_around_tower[0][1] in selected_frames:
    #         runs_around_tower.append(run_around_tower)

    runs_around_tower_to_keep = []

    time_of_rewarded_runsaroundtower = []
    time_of_unrewarded_runsaroundtower = []

    for run_around_tower in runs_around_tower:
        
        # if run_around_tower[3]['num_trapezeswitch'] > 1:
        #     continue

        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]

        #rewarded_direction = finding_tower_rewarded_direction(folder_path_mouse_to_process, session_to_process, time_video_frames=traject_time, frames_of_turn=[start_index, end_index])

        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue
        
        if run_around_tower[3]['Rewarded'] == True:
        
            time_of_rewarded_runsaroundtower.append(run_around_tower[4]['epoch_time'])

        else:

            time_of_unrewarded_runsaroundtower.append(run_around_tower[4]['epoch_time'])


        runs_around_tower_to_keep.append(run_around_tower)
        



    rewarded_turns_time = np.sort(time_of_rewarded_runsaroundtower)
    unrewarded_turns_time = np.sort(time_of_unrewarded_runsaroundtower)

    cumulated_rewarded_turns = np.arange(1, len(rewarded_turns_time) + 1)
    cumulated_unrewarded_turns = np.arange(1, len(unrewarded_turns_time) + 1)

    
    # if rewarded_direction == 'CW': #'[270]':

    #     good_turns_time = CW_times_sorted
    #     bad_turns_time = CCW_times_sorted

    #     cumulated_good_turns = CW_cumulative
    #     cumulated_bad_turns = CCW_cumulative

    # elif rewarded_direction == 'CCW': #'[90]':
        
    #     good_turns_time = CCW_times_sorted
    #     bad_turns_time = CW_times_sorted
        
    #     cumulated_good_turns = CCW_cumulative
    #     cumulated_bad_turns = CW_cumulative
        
    # else:

    #     print('ERROR')

    #     return 
    
    ax.step(rewarded_turns_time, cumulated_rewarded_turns, where='post', label='Rewarded turn', color='violet')
    ax.step(unrewarded_turns_time, cumulated_unrewarded_turns, where='post', label='Unrewarded turn', color='indigo')
    
    if show_xlabel:
        ax.set_xlabel('Time of turn (s)', fontsize=5)
    if show_ylabel:
        ax.set_ylabel('Cumulative number of turns', fontsize=5)

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    
    #ax.set_title('Cumulative Dynamics of CW vs. CCW Runs')
    
    if show_legend:
        ax.legend(frameon=False, fontsize=4)
    
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# %%
def plot_3d_trajectory(x, y, t, time_start=None, time_end=None, ax=None, linewidth=1):
    """
    Plots a 3D trajectory with (x, y) coordinates and time t as the z-axis.
    The color of the trajectory changes gradually from start to end.

    Parameters:
    - ax: 3D subplot axis (from plt.Axes). If None, a new axis will be created.
    - x: array-like, shape (n,)
    - y: array-like, shape (n,)
    - t: array-like, shape (n,)
    - session_number: string, title of the subplot (Session number).
    - mouse_id: string, label for the y-axis on the left (Mouse ID).
    """
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')


    if time_start is None:
        time_start = t[0]
    if time_end is None:
        time_end = t[-1]

    start_idx = np.searchsorted(t, time_start)
    end_idx = np.searchsorted(t, time_end)

    # Extract data from the selected period
    selected_x = x[start_idx:end_idx]
    selected_y = y[start_idx:end_idx]
    selected_t = t[start_idx:end_idx]
    
    # Normalize the time for color mapping
    norm = plt.Normalize(selected_t.min(), selected_t.max())
    colors = cm.viridis(norm(selected_t))

    # Plot 3D line with gradient color
    for i in range(len(selected_x) - 1):
        ax.plot(selected_x[i:i+2], selected_y[i:i+2], selected_t[i:i+2], color=colors[i], linewidth=linewidth)

    # # Set the x and y labels
    # ax.set_xlabel('x-position (cm)')
    # ax.set_ylabel('y-position (cm)')

    # Hide z label, ticks, and tick labels for all axes
    ax.set_zticks([])
    ax.set_xticks([])
    ax.set_yticks([])

    #ax.set_ylabel(f"{mouse_id}")

    # Title with the session number
    #ax.set_title(session_number)

    # Place the mouse ID as a vertical label on the left
    #ax.text2D(-0.1, 0.5, mouse_id, rotation=90, va='center', ha='center', transform=ax.transAxes, fontsize=7)

# %%
def plot_3dtrajectory_mice_sessions(mice_list, sessions_to_plot, path_to_data_folder, time_start=None, time_end=None, axs=None, linewidth=1):
    
    num_mice = len(mice_list)
    num_sessions = len(sessions_to_plot)
        
    # if fig_input==None :

    #     # Dynamically compute figure size (you can adjust scaling factors if needed)
    #     fig_width = num_sessions * 3  # Each subplot has width of 4 units
    #     fig_height = num_mice * 3     # Each subplot has height of 4 units
    

    #     fig, axs = plt.subplots(num_mice, num_sessions, figsize=(fig_width, fig_height), subplot_kw={'projection': '3d'}) # TOM

    # else:

    #     gs = GridSpec(num_mice, num_sessions, figure=fig)
    #     axs = []

    #     for i in range(num_mice):

    #         axs.append([])

    #         for j in range(num_sessions):

    #             axs[i].append(fig.add_subplot(gs[i,j], projection='3d'))

    #     #axs_top = [axs[f"B{i+1}"] for i in range(len(sessions_to_plot)) ]
    #     #axs_bot = [axs[f"B{i+4}"] for i in range(len(sessions_to_plot)) ]

    #     axs = np.array(axs)
    
    # Ensure axs is 2D array, even if there is only one row or column
    if num_mice == 1:
        axs = np.expand_dims(axs, axis=0)
    if num_sessions == 1:
        axs = np.expand_dims(axs, axis=1)

    # Iterate through each mouse
    for mouse_idx, mouse in enumerate(mice_list):
        folder_path_mouse_to_process = os.path.join(path_to_data_folder, mouse)

        # Get the list of sessions for the current mouse
        sessions_to_process = sorted([name for name in os.listdir(folder_path_mouse_to_process)
                                      if os.path.isdir(os.path.join(folder_path_mouse_to_process, name))
                                      and name.startswith('MOU')])

        # Iterate through each session for the current mouse
        for session_idx, session_to_plot_index in enumerate(sessions_to_plot):
            session_to_plot = sessions_to_process[session_to_plot_index]

            # For the first session, extract trapeze and tower data (you can adjust if needed)
            if session_idx == 0:
                trapeze_width, towers_coordinates = get_trapeze_and_tower_data(folder_path_mouse_to_process, session_to_plot)
                all_trapezes_coordinates_cm = generate_trapeze_and_tower_coordinates(towers_coordinates, trapeze_width)[0]

            # Define the pickle file path
            output_pickle_filename = f"{session_to_plot}_basic_processing_output.pickle"
            output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_plot, output_pickle_filename)
            
            # Check if the pickle file exists
            if not os.path.exists(output_pickle_filepath):
                print(f'Pickle file does not exist for session {session_to_plot}, skipping .....')
                continue
            
            # Load the pickle file
            with open(output_pickle_filepath, 'rb') as file:
                session_data = pickle.load(file)
            
            # Get the positions
            positions = np.array(session_data['positions'])
            timeofframes=session_data['timeofframes']
            
            if mouse_idx==0:
                session_id = f'session {session_to_plot_index+1}'
            else:
                session_id = ''
            
            if session_idx==0:
                mouse_id = mouse
            else:
                mouse_id=''

            # Plot the trajectory on the respective subplot

            plot_3d_trajectory(positions[0, :], positions[1, :], timeofframes, ax=axs[mouse_idx, session_idx], time_start=time_start, time_end=time_end, linewidth=linewidth)

            
    
    # Display the plot
    #plt.tight_layout()
    #plt.show()

# %%
def finding_session_rewarded_direction(folder_path_mouse_to_analyse, session_to_analyse):
# Looking for the rewarded direction FOR ALL THE SESSIONS

    # sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
    #                               if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
    #                               and name.startswith('MOU')])

    #output_pickle_filename = f"{sessions_to_analyse[-1]}_basic_analysing_output.pickle"
    #output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, sessions_to_analyse[-1], output_pickle_filename)

    #with open(output_pickle_filepath, 'rb') as file:
    #        session_data = pickle.load(file)

    # session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,sessions_to_analyse[-1])

    session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,session_to_analyse)


    rewarded_direction_degrees = session_param_df["potentialRewardedDirections"][0]

    if rewarded_direction_degrees == '[270]':

        rewarded_direction = 'CW'

    elif rewarded_direction_degrees == '[90]':
        
        rewarded_direction = 'CCW'
        
    elif rewarded_direction_degrees == '[90, 270]':
    
        rewarded_direction = 'both'

    else:

        print('ERROR')

        return 

    return rewarded_direction
    
    #

# %%
def is_injection(folder_path_mouse_to_analyse, session_to_analyse):

    session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,session_to_analyse)

    if 'injectionCNO' in session_param_df.keys():

        bool_injection = not(session_param_df["injectionCNO"][0] == 'none')

    else :

        print("No injectionCNO key")
        bool_injection = False

    return bool_injection

# %%
def when_injection(folder_path_mouse_to_analyse):

    sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
                                    if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
                                    and name.startswith('MOU')])
    
    injection_session_idx = []

    for idx, session in enumerate(sessions_to_analyse):

        if is_injection(folder_path_mouse_to_analyse, session):

            injection_session_idx.append(idx)

            if idx != 0:

                return injection_session_idx

    
    return injection_session_idx

# %%
def check_alternation(folder_path_mouse_to_analyse, session_limit):

    sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
                                    if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
                                    and name.startswith('MOU')])

    sessions_to_analyse = sessions_to_analyse[:session_limit]

    rewarded_direction_per_session = []

    for session in sessions_to_analyse:

        rewarded_direction_per_session.append(finding_session_rewarded_direction(folder_path_mouse_to_analyse, session))

    for i in range(2,len(rewarded_direction_per_session)):

        if rewarded_direction_per_session[i] == rewarded_direction_per_session[i-2]:

            print(f"ERROR: The rewarded direction is not alternating every day for mouse {folder_path_mouse_to_analyse[-7:]} in session {i+1} or {i-1}")
            print(rewarded_direction_per_session)

            return False
        
    return True

# %%
def separate_directions(path_to_data_folder, mice, session_limit=None):

    CW_mice = []
    CCW_mice = []

    for mouse in mice:

        folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)
        
        if not(check_alternation(folder_path_mouse_to_analyse, session_limit)):

            print(f"Excluding {mouse}")

            continue

        # Get the list of sessions
        sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
                                    if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
                                    and name.startswith('MOU')])

        sessions_to_analyse = sessions_to_analyse[:session_limit]

        first_rewarded_direction = finding_session_rewarded_direction(folder_path_mouse_to_analyse, sessions_to_analyse[4])

        if first_rewarded_direction == 'CW':

            CW_mice.append(mouse)

        elif first_rewarded_direction == 'CCW':

            CCW_mice.append(mouse)

        else:
            
            print('No unique rewarded direction')
            return

        when_injection(folder_path_mouse_to_analyse)

    return CW_mice, CCW_mice

# %%
def find_rewarding_range(folder_path_mouse_to_analyse,session_to_analyse):

    session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,session_to_analyse)

    session_type = eval(list(session_param_df['range_maxConsecRewards'])[0])

    return session_type

# %%
def cumulated_turns_time_profile(folder_path_mouse_to_analyse, session_to_analyse, time_start=None, time_end=None):

    output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, session_to_analyse, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    traject_time = session_data['timeofframes']

    if time_start is None:
        time_start = traject_time[0]
    if time_end is None:
        time_end = traject_time[-1]
  
    runs_around_tower = copy.deepcopy(session_data['all_epochs']['run_around_tower'])

    runs_around_tower_to_keep = []

    time_of_runsaroundtower_CW = []
    time_of_runsaroundtower_CCW = []

    for run_around_tower in runs_around_tower:
        
        # if run_around_tower[3]['num_trapezeswitch'] > 1:
        #     continue

        start_index, end_index = run_around_tower[0][0], run_around_tower[0][1]

        if traject_time[start_index]<time_start or traject_time[end_index]>time_end:
        
            continue
        
        if run_around_tower[3]['direction'] == 'CW':
        
            time_of_runsaroundtower_CW.append(run_around_tower[4]['epoch_time'])

        if run_around_tower[3]['direction'] == 'CCW':
        
            time_of_runsaroundtower_CCW.append(run_around_tower[4]['epoch_time'])


        runs_around_tower_to_keep.append(run_around_tower)

    CW_times_sorted = np.sort(time_of_runsaroundtower_CW)
    CCW_times_sorted = np.sort(time_of_runsaroundtower_CCW)

    CW_cumulative = np.arange(1, len(CW_times_sorted) + 1)
    CCW_cumulative = np.arange(1, len(CCW_times_sorted) + 1)

    return [CW_times_sorted, CW_cumulative], [CCW_times_sorted, CCW_cumulative]

# %%
def accumulation_threshold(cummulated_events_time, threshold=0.8):

    i = 0

    if len(cummulated_events_time) != 0:
        
        fraction_of_events = (i+1)/len(cummulated_events_time)
    
    else:

        return 0

    while fraction_of_events<threshold:

        i = i + 1
        fraction_of_events = (i+1)/len(cummulated_events_time)

    return cummulated_events_time[i]

# %% [markdown]
# # Computations

# %%
sessions_to_compare = [34,35,36,37,38]
session_limit = sessions_to_compare[-1] +1
time_start = None
time_end = None
video_resolution = [512,512]

# %%
# Coordinates of the rectangles representing the edges of the setup
# These values are in centimeters
border_zone = [
    [(3, 3), (10, 3), (10, 90), (3, 90)],  # left
    [(3, 3), (3, 9.5), (92, 9.5), (92, 3)],  # down
    [(84, 3), (92, 3), (92, 90), (84, 90)],  # right
    [(3, 83), (3, 90), (92, 90), (92, 83)]   # up
]

trapeze_width = 40

# %%
pause_min_duration = 0.1 #if a stop is shorter than this, merges the two epochs bordering it
run_min_duration = 0.3 #minimal duration of an epoch to be considerd
cut_off_speed = 7 # this value is the speed in cm/s. It is used to detect when the animals stop running. 


#run_epochs, clean_run_epochs = detect_run_epochs(speeds,traject_time)

# %%
# Identifying sessions following a weekend

session_lower_limit = 34
session_upper_limit = 46

days_since_last_session = []
rewarding_range = []

n = 0

for mouse in mice_list:
    
    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)
    
    #print(mouse)
    #print(when_injection(folder_path_mouse_to_analyse))

    # Get the list of sessions
    sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
                                  if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
                                  and name.startswith('MOU')])

    sessions_to_analyse = sessions_to_analyse[session_upper_limit:session_lower_limit]
    #mice_path = '/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/Method_Flex_270_dictionnary.pkl'
    #with open(mice_path, 'rb') as file:
    #    mice_sessions = pickle.load(file)


    days_since_last_session.append([])
    rewarding_range.append([])

    for i in np.arange(1,len(sessions_to_analyse)):

        session_name = sessions_to_analyse[i]
        previous_session_name = sessions_to_analyse[i-1]

        year = int(session_name[8:12]) 
        month = int(session_name[12:14])
        day = int(session_name[14:16])

        previous_year = int(previous_session_name[8:12]) 
        previous_month = int(previous_session_name[12:14])
        previous_day = int(previous_session_name[14:16])

        d0 = date(year, month, day)
        d1 = date(previous_year, previous_month, previous_day)

        delta = d0 - d1

        #sessions_date.append([year,month,day])
        days_since_last_session[n].append(delta.days)
        rewarding_range[n].append(find_rewarding_range(folder_path_mouse_to_analyse,sessions_to_analyse[i]))

    n = n + 1


mice_to_analyse = []
rejected_mice = []

for i in range(len(mice_list)):

    sessions_after_weekend = np.where(np.array(days_since_last_session[i])>1)[0] + 2

    sessions_after_weekend = np.array(sessions_after_weekend)

    elimination_condition = np.logical_and(sessions_after_weekend<20, sessions_after_weekend>2)

    sessions_before_limit = np.where(elimination_condition)[0]

    if sessions_before_limit.size == 0 :

        mice_to_analyse.append(mice_list[i])

        print(f"({mice_list[i]}) Those sessions were done after a weekend:", sessions_after_weekend)
        #print(rewarding_range[i].count([1,2]), 'free exploration sessions')
        print("Keeping this mouse \n")

    else:

        rejected_mice.append(mice_list[i])

        print(f"({mice_list[i]}) Those sessions were done after a weekend:", sessions_after_weekend)
        #print(rewarding_range[i].count([1,2]), 'free exploration sessions')
        print("Removing this mouse \n")
        

# Manually removing mice:

#mice_to_analyse.remove('MOUKA274')
#mice_to_analyse.remove('MOUKA275')
#mice_to_analyse.remove('MOUKA276')
# Out:
# (MOU3974) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU3975) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU3987) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU3988) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU3991) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU3992) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4122) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4123) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4124) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4172) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4175) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4183) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4185) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4186) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4192) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4551) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4552) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4560) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4561) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4562) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4563) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4623) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4624) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4692) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4694) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4695) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4696) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4698) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4703) Those sessions were done after a weekend: []
# Keeping this mouse
#
# (MOU4704) Those sessions were done after a weekend: []
# Keeping this mouse

# %%
len(mice_to_analyse)
# Out:
# 30

# %%
"""# Initialize the dictionary with empty lists for each mouse
#mouse_data_persession = {mouse: [] for mouse in mice_to_analyse}

#mouse_rewardedturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}

#mouse_maximum_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}
#mouse_mean_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}

#mouse_average_speed_persession = {mouse: [] for mouse in mice_to_analyse}

mouse_total_turns_persession = {mouse: [] for mouse in mice_to_analyse}
#mouse_goodturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}
#mouse_total_goodturns_persession = {mouse: [] for mouse in mice_to_analyse}

#mouse_CW_persession = {mouse: [] for mouse in mice_to_analyse}
#mouse_CCW_persession = {mouse: [] for mouse in mice_to_analyse}

mouse_flex_ratio_persession = {mouse: [] for mouse in mice_to_analyse}

mouse_CW_number_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_CCW_number_persession = {mouse: [] for mouse in mice_to_analyse}

mouse_CW_meanspeeds_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_CCW_meanspeeds_persession = {mouse: [] for mouse in mice_to_analyse}

mouse_CW_threshold_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_CCW_threshold_persession = {mouse: [] for mouse in mice_to_analyse}

mouse_mean_CW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}
mouse_mean_CCW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}

mouse_median_CW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}
mouse_median_CCW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}

mouse_mean_run_speed_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_total_runs_persession = {mouse: [] for mouse in mice_to_analyse}


for mouse in mice_to_analyse:
    
    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)
    
    # Get the list of sessions
    sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)
                                  if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))
                                  and name.startswith('MOU')])

    sessions_to_analyse = sessions_to_analyse[session_upper_limit:session_lower_limit]
    
    #mice_path = '/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/Method_Flex_270_dictionnary.pkl'
    #with open(mice_path, 'rb') as file:
    #    mice_sessions = pickle.load(file)

    #sessions_to_analyse = mice_sessions[mouse]



    nb_sessions = len(sessions_to_analyse)
    print(f'Mouse {mouse}. There is/are {nb_sessions} sessions:')
    print(sessions_to_analyse, '\n')


    # analyse each session
    for sessionindex,session_to_analyse in enumerate(sessions_to_analyse):
        #print(f'Getting the pickle file of session {session_to_analyse}')
        print(session_to_analyse, '#######', sessionindex)

        #rewarded_direction = finding_session_rewarded_direction(folder_path_mouse_to_analyse,session_to_analyse)
        
        #session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,session_to_analyse)


        # Define the pickle file path
        output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, session_to_analyse, output_pickle_filename)
        
        # Check if the pickle file already exists
        if not os.path.exists(output_pickle_filepath):
            print(f'Pickle file does not exists for session {session_to_analyse}, skipping .....')
            continue  # Skip loading if the file exists and overwrite is False
        
        # Load the pickle file
        with open(output_pickle_filepath, 'rb') as file:
            session_data = pickle.load(file)



        run_around_tower_sessionresult = session_data['run_around_tower_sessionresult']
        runs_between_towers = session_data['all_epochs']['run_between_towers']
        
        CWRatio = run_around_tower_sessionresult['All']['total_CW']/(run_around_tower_sessionresult['All']['total_CCW']+run_around_tower_sessionresult['All']['total_CW'])
        #print(" CWRatio = ", CWRatio)
        TotalRuns = len(runs_between_towers)
        TotalTurns = run_around_tower_sessionresult['All']['total_CCW']+run_around_tower_sessionresult['All']['total_CW']
        TotalCW = run_around_tower_sessionresult['All']['total_CW']
        TotalCCW = run_around_tower_sessionresult['All']['total_CCW']
        flex_ratio = (TotalCW-TotalCCW)/(TotalCW+TotalCCW)
        #print(" TotalTurns = ", TotalTurns)
        # session_data["all_epochs"]["run_around_tower"][3]['direction']


        ####################

        # if rewarded_direction == 'CW':
            
        #     good_turns = run_around_tower_sessionresult['All']['total_CW']
                
        # elif rewarded_direction == 'CCW':
        
        #     good_turns = run_around_tower_sessionresult['All']['total_CCW']
        
        # else:

        #     good_turns = run_around_tower_sessionresult['All']['total_CW'] + run_around_tower_sessionresult['All']['total_CCW']
        
        ####################

        #turns_max_speed = []
        #turns_mean_speed = []

        mouse_CW_meanspeeds = []
        mouse_CCW_meanspeeds = []

        for n in range(len(session_data["all_epochs"]["run_around_tower"])):
    
            run = session_data["all_epochs"]["run_around_tower"][n]

            if run[3]['direction'] == 'CW':

                mouse_CW_meanspeeds.append(run[4]['epoch_meanspeed'])
            
            elif run[3]['direction'] == 'CCW':
            
                mouse_CCW_meanspeeds.append(run[4]['epoch_meanspeed'])

        runs_mean_speed = []

        for n in range(TotalRuns):
    
            run = runs_between_towers[n]
    
            runs_mean_speed.append(run[3]["meanspeed"])
        
            
        #CW_turns_per_visit = compute_turns_per_visit(folder_path_mouse_to_analyse, session_to_analyse, 'CW')[0]
        #CCW_turns_per_visit = compute_turns_per_visit(folder_path_mouse_to_analyse, session_to_analyse, 'CCW')[0]

            #if run[3]['direction'] == rewarded_direction or rewarded_direction == 'both':
                
            #    turns_max_speed.append(run[4]["epoch_maxspeed"])
            #    turns_mean_speed.append(run[4]["epoch_meanspeed"])
                             

        #[good_turns_time, cumulated_good_turns], [bad_turns_time, cumulated_bad_turns] = cumulated_goodbad_turns_time_profile(folder_path_mouse_to_analyse, session_to_analyse, time_start=None, time_end=None)

        [CW_times_sorted, CW_cumulative], [CCW_times_sorted, CCW_cumulative] = cumulated_turns_time_profile(folder_path_mouse_to_analyse, session_to_analyse, time_start=None, time_end=None)        

        #CW_threshold_time = accumulation_threshold(CW_times_sorted, threshold=0.8)
        #CCW_threshold_time = accumulation_threshold(CCW_times_sorted, threshold=0.8)

        #mouse_data_persession[mouse].append([sessionindex+1,session_data['distance_ran']])
        
        #mouse_maximum_turn_speed_persession[mouse].append([sessionindex+1,np.nanmedian(turns_max_speed)])
        #mouse_mean_turn_speed_persession[mouse].append([sessionindex+1,np.nanmedian(turns_mean_speed)])

        #mouse_average_speed_persession[mouse].append([sessionindex+1,session_data['average_speed']])
        
        #mouse_goodturns_ratio_persession[mouse].append([sessionindex+1,good_turns/TotalTurns])
        mouse_total_turns_persession[mouse].append([sessionindex+1,TotalTurns])
        #mouse_total_goodturns_persession[mouse].append([sessionindex+1, good_turns])
        
        #mouse_CW_threshold_persession[mouse].append([sessionindex+1, CW_threshold_time])
        #mouse_CCW_threshold_persession[mouse].append([sessionindex+1, CCW_threshold_time])

        #mouse_CW_persession[mouse].append([sessionindex+1, run_around_tower_sessionresult['All']['total_CW']])
        #mouse_CCW_persession[mouse].append([sessionindex+1, run_around_tower_sessionresult['All']['total_CCW']])

        mouse_flex_ratio_persession[mouse].append([sessionindex+1, flex_ratio])
        
        mouse_CW_number_persession[mouse].append([sessionindex+1, run_around_tower_sessionresult['All']['total_CW']])
        mouse_CCW_number_persession[mouse].append([sessionindex+1, run_around_tower_sessionresult['All']['total_CCW']])

        mouse_CW_meanspeeds_persession[mouse].append([sessionindex+1, np.nanmedian(mouse_CW_meanspeeds)])
        mouse_CCW_meanspeeds_persession[mouse].append([sessionindex+1, np.nanmedian(mouse_CCW_meanspeeds)])
        #mouse_mean_CW_turns_per_visit[mouse].append([sessionindex+1, np.mean(CW_turns_per_visit)])
        #mouse_mean_CCW_turns_per_visit[mouse].append([sessionindex+1, np.mean(CCW_turns_per_visit)])

        #mouse_median_CW_turns_per_visit[mouse].append([sessionindex+1, np.median(CW_turns_per_visit)])
        #mouse_median_CCW_turns_per_visit[mouse].append([sessionindex+1, np.median(CCW_turns_per_visit)])

        mouse_mean_run_speed_persession[mouse].append([sessionindex+1,np.median(runs_mean_speed)])
        mouse_total_runs_persession[mouse].append([sessionindex+1,TotalRuns])


"""
# Out:
# '# Initialize the dictionary with empty lists for each mouse\n#mouse_data_persession = {mouse: [] for mouse in mice_to_analyse}\n\n#mouse_rewardedturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}\n\n#mouse_maximum_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}\n#mouse_mean_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}\n\n#mouse_average_speed_persession = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_total_turns_persession = {mouse: [] for mouse in mice_to_analyse}\n#mouse_goodturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}\n#mouse_total_goodturns_persession = {mouse: [] for mouse in mice_to_analyse}\n\n#mouse_CW_persession = {mouse: [] for mouse in mice_to_analyse}\n#mouse_CCW_persession = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_flex_ratio_persession = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_CW_number_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_CCW_number_persession = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_CW_meanspeeds_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_CCW_meanspeeds_persession = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_CW_threshold_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_CCW_threshold_persession = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_mean_CW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}\nmouse_mean_CCW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_median_CW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}\nmouse_median_CCW_turns_per_visit = {mouse: [] for mouse in mice_to_analyse}\n\nmouse_mean_run_speed_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_total_runs_persession = {mouse: [] for mouse in mice_to_analyse}\n\n\nfor mouse in mice_to_analyse:\n    \n    folder_path_mouse_to_analyse = os.path.join(path_to_data_folder, mouse)\n    \n    # Get the list of sessions\n    sessions_to_analyse = sorted([name for name in os.listdir(folder_path_mouse_to_analyse)\n                                  if os.path.isdir(os.path.join(folder_path_mouse_to_analyse, name))\n                                  and name.startswith(\'MOU\')])\n\n    sessions_to_analyse = sessions_to_analyse[session_upper_limit:session_lower_limit]\n    \n    #mice_path = \'/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/Method_Flex_270_dictionnary.pkl\'\n    #with open(mice_path, \'rb\') as file:\n    #    mice_sessions = pickle.load(file)\n\n    #sessions_to_analyse = mice_sessions[mouse]\n\n\n\n    nb_sessions = len(sessions_to_analyse)\n    print(f\'Mouse {mouse}. There is/are {nb_sessions} sessions:\')\n    print(sessions_to_analyse, \'\n\')\n\n\n    # analyse each session\n    for sessionindex,session_to_analyse in enumerate(sessions_to_analyse):\n        #print(f\'Getting the pickle file of session {session_to_analyse}\')\n        print(session_to_analyse, \'#######\', sessionindex)\n\n        #rewarded_direction = finding_session_rewarded_direction(folder_path_mouse_to_analyse,session_to_analyse)\n        \n        #session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_analyse,session_to_analyse)\n\n\n        # Define the pickle file path\n        output_pickle_filename = f"{session_to_analyse}_basic_processing_output.pickle"\n        output_pickle_filepath = os.path.join(folder_path_mouse_to_analyse, session_to_analyse, output_pickle_filename)\n        \n        # Check if the pickle file already exists\n        if not os.path.exists(output_pickle_filepath):\n            print(f\'Pickle file does not exists for session {session_to_analyse}, skipping .....\')\n            continue  # Skip loading if the file exists and overwrite is False\n        \n        # Load the pickle file\n        with open(output_pickle_filepath, \'rb\') as file:\n            session_data = pickle.load(file)\n\n\n\n        run_around_tower_sessionresult = session_data[\'run_around_tower_sessionres ...

# %%
"""# Initialize the dictionary with empty lists for each mouse
mouse_data_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_rewardedturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_maximum_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_mean_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_average_speed_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_total_turns_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_goodturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}
mouse_total_goodturns_persession = {mouse: [] for mouse in mice_to_analyse}

for mouse in mice_to_analyse:
    folder_path_mouse_to_process = os.path.join(path_to_data_folder, mouse)
    
    # Get the list of sessions
    sessions_to_process = sorted([name for name in os.listdir(folder_path_mouse_to_process)
                                  if os.path.isdir(os.path.join(folder_path_mouse_to_process, name))
                                  and name.startswith('MOU')])
    
    nb_sessions = len(sessions_to_process)
    print(f'Mouse {mouse}. There is/are {nb_sessions} sessions:')
    print(sessions_to_process, '\n')

    # Looking for the rewarded direction FOR ALL THE SESSIONS
    
  


    #

    # Process each session
    for sessionindex,session_to_process in enumerate(sessions_to_process):
        #print(f'Getting the pickle file of session {session_to_process}')

        rewarded_direction = finding_session_rewarded_direction(folder_path_mouse_to_process,session_to_process)
        
        session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_process,session_to_process)


        # Define the pickle file path
        output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"
        output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)
        
        # Check if the pickle file already exists
        if not os.path.exists(output_pickle_filepath):
            print(f'Pickle file does not exists for session {session_to_process}, skipping .....')
            continue  # Skip loading if the file exists and overwrite is False
        
        # Load the pickle file
        with open(output_pickle_filepath, 'rb') as file:
            session_data = pickle.load(file)

        run_around_tower_sessionresult = session_data['run_around_tower_sessionresult']
        #CWRatio = run_around_tower_sessionresult['All']['total_CW']/(run_around_tower_sessionresult['All']['total_CCW']+run_around_tower_sessionresult['All']['total_CW'])
        TotalTurns = run_around_tower_sessionresult['All']['total_CCW']+run_around_tower_sessionresult['All']['total_CW']
        # session_data["all_epochs"]["run_around_tower"][3]['direction']

        ####################

        if rewarded_direction == 'CW':
            
            good_turns = run_around_tower_sessionresult['All']['total_CW']
                
        elif rewarded_direction == 'CCW':
        
            good_turns = run_around_tower_sessionresult['All']['total_CCW']
        
        else:

            good_turns = run_around_tower_sessionresult['All']['total_CW'] + run_around_tower_sessionresult['All']['total_CCW']
        
        ####################

        turns_max_speed = []
        turns_mean_speed = []

        for n in range(len(session_data["all_epochs"]["run_around_tower"])):
    
            run = session_data["all_epochs"]["run_around_tower"][n]
    
            if run[3]['direction'] == rewarded_direction:
        
                turns_max_speed.append(run[4]["epoch_maxspeed"])
                turns_mean_speed.append(run[4]["epoch_meanspeed"])
        
        mouse_data_persession[mouse].append([sessionindex+1,session_data['distance_ran']])
        
        mouse_maximum_turn_speed_persession[mouse].append([sessionindex+1,np.median(turns_max_speed)])
        mouse_mean_turn_speed_persession[mouse].append([sessionindex+1,np.median(turns_mean_speed)])

        mouse_average_speed_persession[mouse].append([sessionindex+1,session_data['average_speed']])
        
        mouse_goodturns_ratio_persession[mouse].append([sessionindex+1,good_turns/TotalTurns])
        mouse_total_turns_persession[mouse].append([sessionindex+1,TotalTurns])
        mouse_total_goodturns_persession[mouse].append([sessionindex+1, good_turns])



"""
# Out:
# '# Initialize the dictionary with empty lists for each mouse\nmouse_data_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_rewardedturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_maximum_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_mean_turn_speed_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_average_speed_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_total_turns_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_goodturns_ratio_persession = {mouse: [] for mouse in mice_to_analyse}\nmouse_total_goodturns_persession = {mouse: [] for mouse in mice_to_analyse}\n\nfor mouse in mice_to_analyse:\n    folder_path_mouse_to_process = os.path.join(path_to_data_folder, mouse)\n    \n    # Get the list of sessions\n    sessions_to_process = sorted([name for name in os.listdir(folder_path_mouse_to_process)\n                                  if os.path.isdir(os.path.join(folder_path_mouse_to_process, name))\n                                  and name.startswith(\'MOU\')])\n    \n    nb_sessions = len(sessions_to_process)\n    print(f\'Mouse {mouse}. There is/are {nb_sessions} sessions:\')\n    print(sessions_to_process, \'\n\')\n\n    # Looking for the rewarded direction FOR ALL THE SESSIONS\n    \n  \n\n\n    #\n\n    # Process each session\n    for sessionindex,session_to_process in enumerate(sessions_to_process):\n        #print(f\'Getting the pickle file of session {session_to_process}\')\n\n        rewarded_direction = finding_session_rewarded_direction(folder_path_mouse_to_process,session_to_process)\n        \n        session_traj_df, session_turns_df, session_param_df=load_data(folder_path_mouse_to_process,session_to_process)\n\n\n        # Define the pickle file path\n        output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"\n        output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)\n        \n        # Check if the pickle file already exists\n        if not os.path.exists(output_pickle_filepath):\n            print(f\'Pickle file does not exists for session {session_to_process}, skipping .....\')\n            continue  # Skip loading if the file exists and overwrite is False\n        \n        # Load the pickle file\n        with open(output_pickle_filepath, \'rb\') as file:\n            session_data = pickle.load(file)\n\n        run_around_tower_sessionresult = session_data[\'run_around_tower_sessionresult\']\n        #CWRatio = run_around_tower_sessionresult[\'All\'][\'total_CW\']/(run_around_tower_sessionresult[\'All\'][\'total_CCW\']+run_around_tower_sessionresult[\'All\'][\'total_CW\'])\n        TotalTurns = run_around_tower_sessionresult[\'All\'][\'total_CCW\']+run_around_tower_sessionresult[\'All\'][\'total_CW\']\n        # session_data["all_epochs"]["run_around_tower"][3][\'direction\']\n\n        ####################\n\n        if rewarded_direction == \'CW\':\n            \n            good_turns = run_around_tower_sessionresult[\'All\'][\'total_CW\']\n                \n        elif rewarded_direction == \'CCW\':\n        \n            good_turns = run_around_tower_sessionresult[\'All\'][\'total_CCW\']\n        \n        else:\n\n            good_turns = run_around_tower_sessionresult[\'All\'][\'total_CW\'] + run_around_tower_sessionresult[\'All\'][\'total_CCW\']\n        \n        ####################\n\n        turns_max_speed = []\n        turns_mean_speed = []\n\n        for n in range(len(session_data["all_epochs"]["run_around_tower"])):\n    \n            run = session_data["all_epochs"]["run_around_tower"][n]\n    \n            if run[3][\'direction\'] == rewarded_direction:\n        \n                turns_max_speed.append(run[4]["epoch_maxspeed"])\n                turns_mean_speed.append(run[4]["epoch_meanspeed"])\n        \n        mouse_data_persession[mouse].append([sessionindex+1,session_data[\'distance_ran\']])\n   ...

# %%
#CW_mice, CCW_mice = separate_directions(path_to_data_folder, mice_to_analyse, session_limit=session_limit)

# %% [markdown]
# # Figure

# %%
sessions_to_compare = [33,34,35,40,41]

mice_to_compare = ['MOU4551','MOU3988'] #['MOUKA290', 'MOUKA313'] #["MOUKA290","MOUKA300"]

folder_path_mouse_to_process = f"/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/{mice_to_compare[0]}"

session_data_list = []

for i in range(len(sessions_to_compare)):


    session_to_process = session_list[mice_to_compare[0]][sessions_to_compare[i]]
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    session_data_list.append(session_data)

traject_time = session_data['timeofframes']

distances = session_data['distances']
speeds = session_data['speeds']
angular_speeds = session_data['angular_speeds']


###################

# Trapezes_positions
#trapeze_width, towers_coordinates = get_trapeze_and_tower_data(folder_path_mouse_to_process, session_to_process)
#all_trapezes_coordinates_cm = generate_trapeze_and_tower_coordinates(towers_coordinates, trapeze_width)[0]

# 
# Convert all coordinates
# all_trapezes_coordinates_cm = {}
# for tower, trapezes in all_trapezes_coordinates.items():
#     all_trapezes_coordinates_cm[tower] = {}
#     for trapeze, coords in trapezes.items():
#         all_trapezes_coordinates_cm[tower][trapeze] = [convert_pix_to_cm(coord) for coord in coords]

# Print the result for the trapezes

run_epochs, clean_run_epochs= detect_run_epochs(speeds,traject_time)

#runs_between_towers = copy.deepcopy(session_data['all_epochs']['run_between_towers'])


##################################################################################################################################################################################################################

def force_aspect(ax,ratio=1):
    ratio = 1.0
    x_left, x_right = ax.get_xlim()
    y_low, y_high = ax.get_ylim()
    ax.set_aspect(abs((x_right-x_left)/(y_low-y_high))*ratio)

video_resolution = 512, 512 # this gives the resolution in pixel of the video recorded(trajectory of the mice in the maze)  
trapeze_width = 40 # rewards are delivered in the maze around 4 towers,  when mice a switch from one trapze to another

first_epoch_to_plot = 93 # 40 93
last_epoch_to_plot = 99 # 50 99

fig=plt.figure(figsize=(cm2inch(18), cm2inch(23)), dpi=300, constrained_layout=False, facecolor='w')
gs = fig.add_gridspec(5, 1 , hspace=0.35, height_ratios=[1, 1, 1, 1, 1])

#########################################

row1 = gs[0].subgridspec(1, 5, wspace=.3, hspace=.3)

ax_11 = plt.subplot(row1[0,0], projection="3d", aspect="equal")
ax_12 = plt.subplot(row1[0,1], projection="3d", aspect="equal")
ax_13 = plt.subplot(row1[0,2], projection="3d", aspect="equal")
ax_14 = plt.subplot(row1[0,3], projection="3d", aspect="equal")
ax_15 = plt.subplot(row1[0,4], projection="3d", aspect="equal")

axs_1top = [ax_11,ax_12,ax_13,ax_14,ax_15]
axs_1top = np.array(axs_1top)

plot_3dtrajectory_mice_sessions([mice_to_compare[0]], sessions_to_compare, path_to_data_folder, time_start=time_start, time_end=time_end, axs=axs_1top, linewidth=0.5)

ax_11.set_xlabel('x', labelpad=-15)
ax_11.set_ylabel('y', labelpad=-15)
ax_11.set_zlabel('Time', labelpad=-15, rotation='vertical')

ax_11.text2D(-0.2, 0.5, 'Mouse 1 bis', rotation=90, va='center', ha='center', transform=ax_11.transAxes, fontsize=7)

ax_11.text2D(0.5, 1.1, f'Session {sessions_to_compare[0]+1}', va='center', ha='center', transform=ax_11.transAxes, fontsize=7)
ax_12.text2D(0.5, 1.1, f'Session {sessions_to_compare[1]+1}', va='center', ha='center', transform=ax_12.transAxes, fontsize=7)
ax_13.text2D(0.5, 1.1, f'Session {sessions_to_compare[2]+1}', va='center', ha='center', transform=ax_13.transAxes, fontsize=7)
ax_14.text2D(0.5, 1.1, f'Session {sessions_to_compare[3]+1}', va='center', ha='center', transform=ax_14.transAxes, fontsize=7)
ax_15.text2D(0.5, 1.1, f'Session {sessions_to_compare[4]+1}', va='center', ha='center', transform=ax_15.transAxes, fontsize=7)

#fig.text(.09, 0.9, 'A', weight='bold', va='center', ha='center', fontsize=7)


#ax_11.text(-0.6, 1, 'A', weight='bold', va='center', ha='center', transform=ax_11.transAxes, fontsize=7)


#print(start_index, end_index)

#########################################


row2 = gs[1].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_21 = plt.subplot(row2[0], aspect="equal")
ax_22 = plt.subplot(row2[1], aspect="equal")
ax_23 = plt.subplot(row2[2], aspect="equal")
ax_24 = plt.subplot(row2[3], aspect="equal")
ax_25 = plt.subplot(row2[4], aspect="equal")

#ax_21.text(-0.1, 0.5, 'Mouse 1', color='darkorange',rotation=90, va='center', ha='center', transform=ax_21.transAxes, fontsize=7)

ax_2 = [ax_21,ax_22,ax_23,ax_24,ax_25]

# plot_run_type(traject_time, smoothed_Xpositions_cm, smoothed_Ypositions_cm, session_data['all_epochs'], towers_coordinates, ax_21, runtype='run_around_tower', all_trapezes_coordinates_cm=all_trapezes_coordinates_cm, q=4)
# plot_run_type(traject_time, smoothed_Xpositions_cm, smoothed_Ypositions_cm, session_data['all_epochs'], towers_coordinates, ax_22, runtype='run_around_tower', all_trapezes_coordinates_cm=all_trapezes_coordinates_cm, q=4)
# plot_run_type(traject_time, smoothed_Xpositions_cm, smoothed_Ypositions_cm, session_data['all_epochs'], towers_coordinates, ax_23, runtype='run_around_tower', all_trapezes_coordinates_cm=all_trapezes_coordinates_cm, q=4)

for j in range(len(sessions_to_compare)):

    plot_run_type(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[j]], ax_2[j], runtype='run_around_tower', q=4, time_start=time_start, time_end=time_end)

#fig.text(.09, 0.7, 'B', weight='bold', va='center', ha='center', fontsize=7)

#ax_11.text(-0.6, 1, 'B', weight='bold', va='center', ha='center', transform=ax_21.transAxes, fontsize=7)

#########################################

row3 = gs[2].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_31 = plt.subplot(row3[0], aspect="equal")
ax_32 = plt.subplot(row3[1], aspect="equal")
ax_33 = plt.subplot(row3[2], aspect="equal")
ax_34 = plt.subplot(row3[3], aspect="equal")
ax_35 = plt.subplot(row3[4], aspect="equal")

ax_3 = [ax_31,ax_32,ax_33,ax_34,ax_35]


for k in range(len(sessions_to_compare)):

    plot_runs_around_towers_origin(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[k]], ax_3[k], q=4, time_start=time_start, time_end=time_end, show_xlabel= True if k==0 else False, show_ylabel= True if k==0 else False, show_legend= True if k==0 else False, xlim=(-30,30), ylim=(-30,30))
    ax_3[k].set_xticks([-20, 0, 20])
    ax_3[k].set_yticks([-20, 0, 20])

#fig.text(.09, 0.55, 'C', weight='bold', va='center', ha='center', fontsize=7)

#ax_31.text(-0.5, 1, 'C', weight='bold', va='center', ha='center', transform=ax_31.transAxes, fontsize=7)

#########################################

row4 = gs[3].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_41 = plt.subplot(row4[0])
ax_42 = plt.subplot(row4[1])
ax_43 = plt.subplot(row4[2])
ax_44 = plt.subplot(row4[3])
ax_45 = plt.subplot(row4[4])

ax_4 = [ax_41, ax_42, ax_43, ax_44, ax_45]

for l in range(len(sessions_to_compare)):

    plot_runs_around_speed_profiles(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[l]], ax_4[l], time_start=time_start, time_end=time_end, xlim=(0,2), ylim=(0,80), show_xlabel= True if l==0 else False, show_ylabel= True if l==0 else False, show_color_bar= True if l==0 else False)

force_aspect(ax_41)
force_aspect(ax_42)
force_aspect(ax_43)
force_aspect(ax_44)
force_aspect(ax_45)


#fig.text(.09, 0.37, 'D', weight='bold', va='center', ha='center', fontsize=7)

#ax_41.text(-0.2, 1, 'D', weight='bold', va='center', ha='center', transform=ax_41.transAxes, fontsize=7)

#########################################

row5 = gs[4].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_51 = plt.subplot(row5[0])
ax_52 = plt.subplot(row5[1])
ax_53 = plt.subplot(row5[2])
ax_54 = plt.subplot(row5[3])
ax_55 = plt.subplot(row5[4])

ax_5 = [ax_51, ax_52, ax_53, ax_54, ax_55]

for m in range(len(sessions_to_compare)):

    show_xlabel= True if m==0 else False
    show_ylabel = True if m==0 else False
    xlim = [0,600]
    ylim = [0,250]

    plot_cumulated_turns_time_profile(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[m]], ax_5[m], time_start=time_start, time_end=time_end, xlim=xlim, ylim=ylim , show_xlabel=show_xlabel, show_ylabel=show_ylabel, show_legend= True if m==0 else False)

force_aspect(ax_51)
force_aspect(ax_52)
force_aspect(ax_53)
force_aspect(ax_54)
force_aspect(ax_55)

#fig.text(.09, 0.2, 'E', weight='bold', va='center', ha='center', fontsize=7)

#ax_41.text(-0.2, 1, 'E', weight='bold', va='center', ha='center', transform=ax_51.transAxes, fontsize=7)

#########################################



plt.show()

# %%
-
# Out:
#   Cell In[37], line 1
#     -
#      ^
# SyntaxError: invalid syntax

# %%
sessions_to_compare = [39,40,41,42,43]


mice_to_compare = ['MOU4551'] #['MOUKA290', 'MOUKA313'] #["MOUKA290","MOUKA300"]

folder_path_mouse_to_process = f"/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/{mice_to_compare[0]}"

session_data_list = []

for i in range(len(sessions_to_compare)):


    session_to_process = session_list[mice_to_compare[0]][sessions_to_compare[i]]
    output_pickle_filename = f"{session_to_process}_basic_processing_output.pickle"        
    output_pickle_filepath = os.path.join(folder_path_mouse_to_process, session_to_process, output_pickle_filename)

    with open(output_pickle_filepath, 'rb') as file:
        session_data = pickle.load(file)

    session_data_list.append(session_data)

traject_time = session_data['timeofframes']

distances = session_data['distances']
speeds = session_data['speeds']
angular_speeds = session_data['angular_speeds']


###################

# Trapezes_positions
#trapeze_width, towers_coordinates = get_trapeze_and_tower_data(folder_path_mouse_to_process, session_to_process)
#all_trapezes_coordinates_cm = generate_trapeze_and_tower_coordinates(towers_coordinates, trapeze_width)[0]

# 
# Convert all coordinates
# all_trapezes_coordinates_cm = {}
# for tower, trapezes in all_trapezes_coordinates.items():
#     all_trapezes_coordinates_cm[tower] = {}
#     for trapeze, coords in trapezes.items():
#         all_trapezes_coordinates_cm[tower][trapeze] = [convert_pix_to_cm(coord) for coord in coords]

# Print the result for the trapezes

run_epochs, clean_run_epochs= detect_run_epochs(speeds,traject_time)

#runs_between_towers = copy.deepcopy(session_data['all_epochs']['run_between_towers'])


##################################################################################################################################################################################################################

def force_aspect(ax,ratio=1):
    ratio = 1.0
    x_left, x_right = ax.get_xlim()
    y_low, y_high = ax.get_ylim()
    ax.set_aspect(abs((x_right-x_left)/(y_low-y_high))*ratio)

video_resolution = 512, 512 # this gives the resolution in pixel of the video recorded(trajectory of the mice in the maze)  
trapeze_width = 40 # rewards are delivered in the maze around 4 towers,  when mice a switch from one trapze to another

first_epoch_to_plot = 93 # 40 93
last_epoch_to_plot = 99 # 50 99

fig=plt.figure(figsize=(cm2inch(18), cm2inch(23)), dpi=300, constrained_layout=False, facecolor='w')
gs = fig.add_gridspec(5, 1 , hspace=0.35, height_ratios=[1, 1, 1, 1, 1])

#########################################

row1 = gs[0].subgridspec(1, 5, wspace=.3, hspace=.3)

ax_11 = plt.subplot(row1[0,0], projection="3d", aspect="equal")
ax_12 = plt.subplot(row1[0,1], projection="3d", aspect="equal")
ax_13 = plt.subplot(row1[0,2], projection="3d", aspect="equal")
ax_14 = plt.subplot(row1[0,3], projection="3d", aspect="equal")
ax_15 = plt.subplot(row1[0,4], projection="3d", aspect="equal")

axs_1top = [ax_11,ax_12,ax_13,ax_14,ax_15]
axs_1top = np.array(axs_1top)

#plot_3dtrajectory_mice_sessions([mice_to_compare[0]], sessions_to_compare, path_to_data_folder, time_start=time_start, time_end=time_end, axs=axs_1top, linewidth=0.5)

ax_11.set_xlabel('x', labelpad=-15)
ax_11.set_ylabel('y', labelpad=-15)
ax_11.set_zlabel('Time', labelpad=-15, rotation='vertical')

ax_11.text2D(-0.2, 0.5, 'Mouse 1 bis', rotation=90, va='center', ha='center', transform=ax_11.transAxes, fontsize=7)

ax_11.text2D(0.5, 1.1, f'Session {sessions_to_compare[0]+1}', va='center', ha='center', transform=ax_11.transAxes, fontsize=7)
ax_12.text2D(0.5, 1.1, f'Session {sessions_to_compare[1]+1}', va='center', ha='center', transform=ax_12.transAxes, fontsize=7)
ax_13.text2D(0.5, 1.1, f'Session {sessions_to_compare[2]+1}', va='center', ha='center', transform=ax_13.transAxes, fontsize=7)
ax_14.text2D(0.5, 1.1, f'Session {sessions_to_compare[3]+1}', va='center', ha='center', transform=ax_14.transAxes, fontsize=7)
ax_15.text2D(0.5, 1.1, f'Session {sessions_to_compare[4]+1}', va='center', ha='center', transform=ax_15.transAxes, fontsize=7)

fig.text(.09, 0.9, 'A', weight='bold', va='center', ha='center', fontsize=7)


#ax_11.text(-0.6, 1, 'A', weight='bold', va='center', ha='center', transform=ax_11.transAxes, fontsize=7)


#print(start_index, end_index)

#########################################


row2 = gs[1].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_21 = plt.subplot(row2[0], aspect="equal")
ax_22 = plt.subplot(row2[1], aspect="equal")
ax_23 = plt.subplot(row2[2], aspect="equal")
ax_24 = plt.subplot(row2[3], aspect="equal")
ax_25 = plt.subplot(row2[4], aspect="equal")

#ax_21.text(-0.1, 0.5, 'Mouse 1', color='darkorange',rotation=90, va='center', ha='center', transform=ax_21.transAxes, fontsize=7)

ax_2 = [ax_21,ax_22,ax_23,ax_24,ax_25]

# plot_run_type(traject_time, smoothed_Xpositions_cm, smoothed_Ypositions_cm, session_data['all_epochs'], towers_coordinates, ax_21, runtype='run_around_tower', all_trapezes_coordinates_cm=all_trapezes_coordinates_cm, q=4)
# plot_run_type(traject_time, smoothed_Xpositions_cm, smoothed_Ypositions_cm, session_data['all_epochs'], towers_coordinates, ax_22, runtype='run_around_tower', all_trapezes_coordinates_cm=all_trapezes_coordinates_cm, q=4)
# plot_run_type(traject_time, smoothed_Xpositions_cm, smoothed_Ypositions_cm, session_data['all_epochs'], towers_coordinates, ax_23, runtype='run_around_tower', all_trapezes_coordinates_cm=all_trapezes_coordinates_cm, q=4)

for j in range(len(sessions_to_compare)):

    plot_run_type(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[j]], ax_2[j], runtype='run_around_tower', q=4, time_start=time_start, time_end=time_end)

fig.text(.09, 0.7, 'B', weight='bold', va='center', ha='center', fontsize=7)

#ax_11.text(-0.6, 1, 'B', weight='bold', va='center', ha='center', transform=ax_21.transAxes, fontsize=7)

#########################################

row3 = gs[2].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_31 = plt.subplot(row3[0], aspect="equal")
ax_32 = plt.subplot(row3[1], aspect="equal")
ax_33 = plt.subplot(row3[2], aspect="equal")
ax_34 = plt.subplot(row3[3], aspect="equal")
ax_35 = plt.subplot(row3[4], aspect="equal")

ax_3 = [ax_31,ax_32,ax_33,ax_34,ax_35]


for k in range(len(sessions_to_compare)):

    plot_runs_around_towers_origin(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[k]], ax_3[k], q=4, time_start=time_start, time_end=time_end, show_xlabel= True if k==0 else False, show_ylabel= True if k==0 else False, show_legend= True if k==0 else False, xlim=(-30,30), ylim=(-30,30))
    ax_3[k].set_xticks([-20, 0, 20])
    ax_3[k].set_yticks([-20, 0, 20])

fig.text(.09, 0.55, 'C', weight='bold', va='center', ha='center', fontsize=7)

#ax_31.text(-0.5, 1, 'C', weight='bold', va='center', ha='center', transform=ax_31.transAxes, fontsize=7)

#########################################

row4 = gs[3].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_41 = plt.subplot(row4[0])
ax_42 = plt.subplot(row4[1])
ax_43 = plt.subplot(row4[2])
ax_44 = plt.subplot(row4[3])
ax_45 = plt.subplot(row4[4])

ax_4 = [ax_41, ax_42, ax_43, ax_44, ax_45]

for l in range(len(sessions_to_compare)):

    plot_runs_around_speed_profiles(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[l]], ax_4[l], time_start=time_start, time_end=time_end, xlim=(0,2), ylim=(0,80), show_xlabel= True if l==0 else False, show_ylabel= True if l==0 else False, show_color_bar= True if l==0 else False)

force_aspect(ax_41)
force_aspect(ax_42)
force_aspect(ax_43)
force_aspect(ax_44)
force_aspect(ax_45)


fig.text(.09, 0.37, 'D', weight='bold', va='center', ha='center', fontsize=7)

#ax_41.text(-0.2, 1, 'D', weight='bold', va='center', ha='center', transform=ax_41.transAxes, fontsize=7)

#########################################

row5 = gs[4].subgridspec(1, 5, wspace=.3, hspace=.1)

ax_51 = plt.subplot(row5[0])
ax_52 = plt.subplot(row5[1])
ax_53 = plt.subplot(row5[2])
ax_54 = plt.subplot(row5[3])
ax_55 = plt.subplot(row5[4])

ax_5 = [ax_51, ax_52, ax_53, ax_54, ax_55]

for m in range(len(sessions_to_compare)):

    show_xlabel= True if m==0 else False
    show_ylabel = True if m==0 else False
    xlim = [0,600]
    ylim = [0,None]

    plot_cumulated_turns_time_profile(folder_path_mouse_to_process, session_list[mice_to_compare[0]][sessions_to_compare[m]], ax_5[m], time_start=time_start, time_end=time_end, xlim=xlim, ylim=ylim , show_xlabel=show_xlabel, show_ylabel=show_ylabel, show_legend= False)

force_aspect(ax_51)
force_aspect(ax_52)
force_aspect(ax_53)
force_aspect(ax_54)
force_aspect(ax_55)

fig.text(.09, 0.2, 'E', weight='bold', va='center', ha='center', fontsize=7)

#ax_41.text(-0.2, 1, 'E', weight='bold', va='center', ha='center', transform=ax_51.transAxes, fontsize=7)

#########################################
 


plt.show()

# %%
sessions_to_analyse[45]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 sessions_to_analyse[45]
#
# IndexError: list index out of range

# %%
folder_path_mouse_to_process = '/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/MOU4551/'

output_pickle_filepath = os.path.join(folder_path_mouse_to_process, 'MOU4551_20240804-1201/MOU4551_20240804-1201_basic_processing_output.pickle')

# Load the pickle file
with open(output_pickle_filepath, 'rb') as file:
    session_data = pickle.load(file)

# %%
for run_index, run_around_tower in enumerate(runs_around_tower):
        run_start_index = run_around_tower[0][0]
        run_end_index = run_around_tower[0][1]
        start_stop_times_run_epoch = [time_video_frames[run_start_index], time_video_frames[run_end_index]]
        
        # Find the relevant entries in turns_df within the run epoch
        condition = (turns_df['time'] >= start_stop_times_run_epoch[0]) & (turns_df['time'] <= start_stop_times_run_epoch[1])
        if not condition.any():
            continue
        
        switch_in_turns_df = turns_df[condition]
        num_trapezeswitch = switch_in_turns_df.shape[0]
        
        # Initialize the type_of_turn dictionary

        is_maxNberOfConsecRewards = 'maxNberOfConsecRewards' in switch_in_turns_df.keys()

# %%
session_data['all_epochs']['run_around_tower']
# Out:
# [[[65, 83],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(17.637),
#    'epoch_duration': np.float64(0.7190000000000012),
#    'epoch_distance': np.float64(18.98800660587051),
#    'epoch_meanspeed': np.float64(26.408910439319165),
#    'epoch_maxspeed': np.float64(61.86285763033723)}],
#  [[87, 102],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(18.518),
#    'epoch_duration': np.float64(0.5999999999999979),
#    'epoch_distance': np.float64(17.940424585799757),
#    'epoch_meanspeed': np.float64(29.900707642999702),
#    'epoch_maxspeed': np.float64(53.61753690692798)}],
#  [[150, 168],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(21.038),
#    'epoch_duration': np.float64(0.7199999999999989),
#    'epoch_distance': np.float64(11.085607290698878),
#    'epoch_meanspeed': np.float64(15.396676792637354),
#    'epoch_maxspeed': np.float64(35.13765750649412)}],
#  [[169, 185],
#   ['SW', 'W'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(21.8),
#    'epoch_duration': np.float64(0.6379999999999981),
#    'epoch_distance': np.float64(16.07485060199733),
#    'epoch_meanspeed': np.float64(25.19569059874197),
#    'epoch_maxspeed': np.float64(46.05066157633064)}],
#  [[185, 202],
#   ['SW', 'N'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(22.438),
#    'epoch_duration': np.float64(0.6799999999999997),
#    'epoch_distance': np.float64(18.04020486541864),
#    'epoch_meanspeed': np.float64(26.529713037380365),
#    'epoch_maxspeed': np.float64(47.598526032990264)}],
#  [[203, 223],
#   ['SW', 'E'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(23.158),
#    'epoch_duration': np.float64(0.8019999999999996),
#    'epoch_distance': np.float64(19.06382703738122),
#    'epoch_meanspeed': np.float64(23.770357901971607),
#    'epoch_maxspeed': np.float64(52.8589664012052)}],
#  [[254, 284],
#   ['SE', 'S'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(25.2),
#    'epoch_duration': np.float64(1.2010000000000005),
#    'epoch_distance': np.float64(16.87528642158793),
#    'epoch_meanspeed': np.float64(14.051029493412091),
#    'epoch_maxspeed': np.float64(32.849570373808604)}],
#  [[287, 318],
#   ['SE', 'S'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(26.52),
#    'epoch_duration': np.float64(1.2420000000000009),
#    'epoch_distance': np.float64(33.509623988328904),
#    'epoch_meanspeed': np.float64(26.98037358158525),
#    'epoch_maxspeed': np.float64(55.76709965806427)}],
#  [[344, 358],
#   ['NE', 'E'],
#   ['NE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(28.801),
#    'epoch_duration': np.float64(0.5600000000000023),
#    'epoch_distance': np.float64(11.125460234531372),
#    'epoch_meanspeed': np.float64(19.866893275948797),
#    'epoch_maxspeed': np.float64(38.07457722622887)}],
#  [[360, 376],
#   ['NE', 'S'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(29.442),
#    'epoch_duration': np.float64(0.6400000000000006),
#    'epoch_distance': np.float64(17.958147361960968),
#    'epoch_meanspeed': np.float64(28.05960525306399),
#    'epoch_maxspeed': np.float64(57.5895400061851)}],
#  [[449, 479],
#   ['SW', 'W'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(33.004),
#    'epoch_duration': np.float64(1.2010000000000005),
#    'epoch_distance': np.float64(33.06062903729437),
#    'epoch_meanspeed': np.float64(27.527584543958664),
#    'epoch_maxspeed': np.float64(56.3607871017986)}],
#  [[552, 570],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(37.125),
#    'epoch_duration': np.float64(0.7220000000000013),
#    'epoch_distance': np.float64(12.0361905883885),
#    'epoch_meanspeed': np.float64(16.67062408364055),
#    'epoch_maxspeed': np.float64(37.75320991640285)}],
#  [[570, 607],
#   ['NW', 'E'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(37.847),
#    'epoch_duration': np.float64(1.4799999999999969),
#    'epoch_distance': np.float64(37.99104136374435),
#    'epoch_meanspeed': np.float64(25.669622543070563),
#    'epoch_maxspeed': np.float64(55.56124246343291)}],
#  [[611, 630],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(39.487),
#    'epoch_duration': np.float64(0.7609999999999957),
#    'epoch_distance': np.float64(18.18719327555306),
#    'epoch_meanspeed': np.float64(23.89907132135764),
#    'epoch_maxspeed': np.float64(52.5853441415601)}],
#  [[637, 654],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(40.528),
#    'epoch_duration': np.float64(0.6799999999999997),
#    'epoch_distance': np.float64(20.73133565425111),
#    'epoch_meanspeed': np.float64(30.487258315075177),
#    'epoch_maxspeed': np.float64(63.362544916659076)}],
#  [[860, 882],
#   ['NE', 'N'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(49.452),
#    'epoch_duration': np.float64(0.8810000000000002),
#    'epoch_distance': np.float64(11.711128315732575),
#    'epoch_meanspeed': np.float64(13.292994683010864),
#    'epoch_maxspeed': np.float64(35.09549101809109)}],
#  [[903, 920],
#   ['NW', 'S'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 3,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(51.174),
#    'epoch_duration': np.float64(0.6809999999999974),
#    'epoch_distance': np.float64(18.318665378876666),
#    'epoch_meanspeed': np.float64(26.89965547558992),
#    'epoch_maxspeed': np.float64(50.62541558022397)}],
#  [[921, 937],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(51.894),
#    'epoch_duration': np.float64(0.642000000000003),
#    'epoch_distance': np.float64(11.846899014765356),
#    'epoch_meanspeed': np.float64(18.45311373016402),
#    'epoch_maxspeed': np.float64(40.88541353238988)}],
#  [[996, 1012],
#   ['NE', 'E'],
#   ['NE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(54.896),
#    'epoch_duration': np.float64(0.6400000000000006),
#    'epoch_distance': np.float64(20.119305175288765),
#    'epoch_meanspeed': np.float64(31.43641433638867),
#    'epoch_maxspeed': np.float64(64.5613771679186)}],
#  [[1056, 1072],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(57.298),
#    'epoch_duration': np.float64(0.6379999999999981),
#    'epoch_distance': np.float64(10.660056072660158),
#    'epoch_meanspeed': np.float64(16.708551838025375),
#    'epoch_maxspeed': np.float64(36.24665050857536)}],
#  [[1073, 1090],
#   ['SW', 'W'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(57.976),
#    'epoch_duration': np.float64(0.6809999999999974),
#    'epoch_distance': np.float64(16.263204217654057),
#    'epoch_meanspeed': np.float64(23.881357147803406),
#    'epoch_maxspeed': np.float64(46.00755888672775)}],
#  [[1091, 1107],
#   ['SW', 'N'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(58.697),
#    'epoch_duration': np.float64(0.6409999999999982),
#    'epoch_distance': np.float64(17.828426453835107),
#    'epoch_meanspeed': np.float64(27.813457806295094),
#    'epoch_maxspeed': np.float64(49.030289634472354)}],
#  [[1161, 1177],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(61.499),
#    'epoch_duration': np.float64(0.6430000000000007),
#    'epoch_distance': np.float64(15.590287323089036),
#    'epoch_meanspeed': np.float64(24.246170020356175),
#    'epoch_maxspeed': np.float64(45.42944537136947)}],
#  [[1179, 1196],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(62.22),
#    'epoch_duration': np.float64(0.6780000000000044),
#    'epoch_distance': np.float64(17.30583500707412),
#    'epoch_meanspeed': np.float64(25.524830393914467),
#    'epoch_maxspeed': np.float64(49.53269170751497)}],
#  [[1199, 1216],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(63.02),
#    'epoch_duration': np.float64(0.6809999999999974),
#    'epoch_distance': np.float64(19.28210765562708),
#    'epoch_meanspeed': np.float64(28.31440184379905),
#    'epoch_maxspeed': np.float64(47.69354365476006)}],
#  [[1216, 1234],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(63.701),
#    'epoch_duration': np.float64(0.720000000000006),
#    'epoch_distance': np.float64(17.67023465976712),
#    'epoch_meanspeed': np.float64(24.541992583009687),
#    'epoch_maxspeed': np.float64(42.12904641561229)}],
#  [[1259, 1276],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(65.421),
#    'epoch_duration': np.float64(0.6809999999999974),
#    'epoch_distance': np.float64(16.226852455724153),
#    'epoch_meanspeed': np.float64(23.827977174338056),
#    'epoch_maxspeed': np.float64(47.39828912502328)}],
#  [[1276, 1291],
#   ['SW', 'W'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(66.102),
#    'epoch_duration': np.float64(0.5989999999999895),
#    'epoch_distance': np.float64(9.953797911774796),
#    'epoch_meanspeed': np.float64(16.61735878426539),
#    'epoch_maxspeed': np.float64(33.41365587494984)}],
#  [[1291, 1307],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(66.701),
#    'epoch_duration': np.float64(0.6430000000000007),
#    'epoch_distance': np.float64(10.818504948647412),
#    'epoch_meanspeed': np.float64(16.825046576434527),
#    'epoch_maxspeed': np.float64(29.28049688651057)}],
#  [[1397, 1420],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(70.944),
#    'epoch_duration': np.float64(0.9209999999999923),
#    'epoch_distance': np.float64(11.102989215632387),
#    'epoch_meanspeed': np.float64(12.05536288342289),
#    'epoch_maxspeed': np.float64(33.21650143586716)}],
#  [[1426, 1444],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(72.105),
#    'epoch_duration': np.float64(0.7209999999999894),
#    'epoch_distance': np.float64(19.296121167439665),
#    'epoch_meanspeed': np.float64(26.762997458307833),
#    'epoch_maxspeed': np.float64(54.889970841250616)}],
#  [[1449, 1466],
#   ['NW', 'E'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(73.025),
#    'epoch_duration': np.float64(0.6799999999999926),
#    'epoch_distance': np.float64(20.512978081005006),
#    'epoch_meanspeed': np.float64(30.166144236772396),
#    'epoch_maxspeed': np.float64(62.409364825364335)}],
#  [[1468, 1486],
#   ['NW', 'S'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(73.784),
#    'epoch_duration': np.float64(0.7219999999999942),
#    'epoch_distance': np.float64(17.283395360694556),
#    'epoch_meanspeed': np.float64(23.938220721183786),
#    'epoch_maxspeed': np.float64(44.41748611703349)}],
#  [[1487, 1505],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(74.547),
#    'epoch_duration': np.float64(0.7190000000000083),
#    'epoch_distance': np.float64(11.894639660466131),
#    'epoch_meanspeed': np.float64(16.54330968075938),
#    'epoch_maxspeed': np.float64(35.78344369944662)}],
#  [[1517, 1533],
#   ['NW', 'S'],
#   ['NW', 'E'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(75.748),
#    'epoch_duration': np.float64(0.6389999999999958),
#    'epoch_distance': np.float64(19.098569649892934),
#    'epoch_meanspeed': np.float64(29.88821541454313),
#    'epoch_maxspeed': np.float64(57.65395100119517)}],
#  [[1542, 1560],
#   ['NW', 'E'],
#   ['NW', 'N'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(76.748),
#    'epoch_duration': np.float64(0.7179999999999893),
#    'epoch_distance': np.float64(19.921688506311675),
#    'epoch_meanspeed': np.float64(27.74608427062949),
#    'epoch_maxspeed': np.float64(60.436281905138344)}],
#  [[1585, 1601],
#   ['NW', 'N'],
#   ['NW', 'W'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(78.47),
#    'epoch_duration': np.float64(0.6380000000000052),
#    'epoch_distance': np.float64(17.900628340402374),
#    'epoch_meanspeed': np.float64(28.05741119185302),
#    'epoch_maxspeed': np.float64(58.60480324576818)}],
#  [[1610, 1632],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(79.469),
#    'epoch_duration': np.float64(0.8810000000000002),
#    'epoch_distance': np.float64(19.19710914711444),
#    'epoch_meanspeed': np.float64(21.790135240765533),
#    'epoch_maxspeed': np.float64(49.524348252400195)}],
#  [[1660, 1677],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(81.469),
#    'epoch_duration': np.float64(0.6810000000000116),
#    'epoch_distance': np.float64(17.389893563237717),
#    'epoch_meanspeed': np.float64(25.535820210333952),
#    'epoch_maxspeed': np.float64(41.56546760647504)}],
#  [[1685, 1701],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(82.47),
#    'epoch_duration': np.float64(0.6410000000000053),
#    'epoch_distance': np.float64(20.010932749911653),
#    'epoch_meanspeed': np.float64(31.2183038220148),
#    'epoch_maxspeed': np.float64(62.81528167682551)}],
#  [[1702, 1721],
#   ['NW', 'E'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(83.148),
#    'epoch_duration': np.float64(0.7620000000000005),
#    'epoch_distance': np.float64(23.38551227334788),
#    'epoch_meanspeed': np.float64(30.68964865268749),
#    'epoch_maxspeed': np.float64(63.823552343020495)}],
#  [[1726, 1744],
#   ['NW', 'S'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(84.111),
#    'epoch_duration': np.float64(0.7199999999999989),
#    'epoch_distance': np.float64(14.452607302347106),
#    'epoch_meanspeed': np.float64(20.073065697704347),
#    'epoch_maxspeed': np.float64(41.453830855712454)}],
#  [[1791, 1808],
#   ['NW', 'S'],
#   ['NW', 'E'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(86.711),
#    'epoch_duration': np.float64(0.6820000000000022),
#    'epoch_distance': np.float64(17.516035761179594),
#    'epoch_meanspeed': np.float64(25.683336893225132),
#    'epoch_maxspeed': np.float64(52.866441945548615)}],
#  [[1815, 1831],
#   ['NW', 'E'],
#   ['NW', 'N'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(87.671),
#    'epoch_duration': np.float64(0.6419999999999959),
#    'epoch_distance': np.float64(19.95336650649932),
#    'epoch_meanspeed': np.float64(31.080010134734344),
#    'epoch_maxspeed': np.float64(60.7060116240093)}],
#  [[1855, 1874],
#   ['NW', 'N'],
#   ['NW', 'W'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(89.275),
#    'epoch_duration': np.float64(0.7569999999999908),
#    'epoch_distance': np.float64(17.433137159705602),
#    'epoch_meanspeed': np.float64(23.02924327570121),
#    'epoch_maxspeed': np.float64(59.59804305920666)}],
#  [[1880, 1896],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(90.275),
#    'epoch_duration': np.float64(0.6400000000000006),
#    'epoch_distance': np.float64(19.040278185439156),
#    'epoch_meanspeed': np.float64(29.750434664748656),
#    'epoch_maxspeed': np.float64(65.29307865163983)}],
#  [[1948, 1967],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(92.996),
#    'epoch_duration': np.float64(0.7600000000000051),
#    'epoch_distance': np.float64(10.986557709620156),
#    'epoch_meanspeed': np.float64(14.455996986342212),
#    'epoch_maxspeed': np.float64(33.40465089451722)}],
#  [[1968, 1986],
#   ['SW', 'W'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(93.797),
#    'epoch_duration': np.float64(0.7199999999999989),
#    'epoch_distance': np.float64(17.11553157307395),
#    'epoch_meanspeed': np.float64(23.771571629269413),
#    'epoch_maxspeed': np.float64(45.94215714233326)}],
#  [[1987, 2003],
#   ['SW', 'N'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(94.557),
#    'epoch_duration': np.float64(0.6400000000000006),
#    'epoch_distance': np.float64(10.39132834572396),
#    'epoch_meanspeed': np.float64(16.236450540193673),
#    'epoch_maxspeed': np.float64(30.736618780005188)}],
#  [[2010, 2027],
#   ['SW', 'W'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(95.475),
#    'epoch_duration': np.float64(0.6820000000000022),
#    'epoch_distance': np.float64(17.193272535420327),
#    'epoch_meanspeed': np.float64(25.210077031408023),
#    'epoch_maxspeed': np.float64(47.858951282515484)}],
#  [[2079, 2097],
#   ['NE', 'N'],
#   ['NE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(98.239),
#    'epoch_duration': np.float64(0.7199999999999989),
#    'epoch_distance': np.float64(12.333886920300094),
#    'epoch_meanspeed': np.float64(17.130398500416824),
#    'epoch_maxspeed': np.float64(36.61020298111103)}],
#  [[2101, 2136],
#   ['NE', 'E'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(99.121),
#    'epoch_duration': np.float64(1.399000000000001),
#    'epoch_distance': np.float64(38.63813456788147),
#    'epoch_meanspeed': np.float64(27.618394973467797),
#    'epoch_maxspeed': np.float64(66.22143851712579)}],
#  [[2139, 2157],
#   ['NE', 'W'],
#   ['NE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(100.638),
#    'epoch_duration': np.float64(0.722999999999999),
#    'epoch_distance': np.float64(10.711353034231488),
#    'epoch_meanspeed': np.float64(14.815149424939838),
#    'epoch_maxspeed': np.float64(27.43160481734785)}],
#  [[2209, 2225],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(103.443),
#    'epoch_duration': np.float64(0.6389999999999958),
#    'epoch_distance': np.float64(10.931624595235),
#    'epoch_meanspeed': np.float64(17.10739373276224),
#    'epoch_maxspeed': np.float64(31.886016829403395)}],
#  [[2226, 2245],
#   ['NW', 'N'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(104.122),
#    'epoch_duration': np.float64(0.7620000000000005),
#    'epoch_distance': np.float64(11.612731242426491),
#    'epoch_meanspeed': np.float64(15.23980478008725),
#    'epoch_maxspeed': np.float64(33.63657674754594)}],
#  [[2305, 2321],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(107.285),
#    'epoch_duration': np.float64(0.63900000000001),
#    'epoch_distance': np.float64(11.44909267317281),
#    'epoch_meanspeed': np.float64(17.917202931412568),
#    'epoch_maxspeed': np.float64(30.739351234969952)}],
#  [[2328, 2345],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(108.203),
#    'epoch_duration': np.float64(0.6809999999999974),
#    'epoch_distance': np.float64(16.603963906779175),
#    'epoch_meanspeed': np.float64(24.381738482788897),
#    'epoch_maxspeed': np.float64(50.225060969042126)}],
#  [[2354, 2372],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(109.243),
#    'epoch_duration': np.float64(0.722999999999999),
#    'epoch_distance': np.float64(19.35675389813886),
#    'epoch_meanspeed': np.float64(26.7728269683802),
#    'epoch_maxspeed': np.float64(45.278299450044784)}],
#  [[2381, 2400],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(110.324),
#    'epoch_duration': np.float64(0.7609999999999957),
#    'epoch_distance': np.float64(18.162965574428917),
#    'epoch_meanspeed': np.float64(23.867234657593983),
#    'epoch_maxspeed': np.float64(41.06585466617088)}],
#  [[2408, 2425],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(111.405),
#    'epoch_duration': np.float64(0.6829999999999927),
#    'epoch_distance': np.float64(16.388034005401973),
#    'epoch_meanspeed': np.float64(23.99419327291676),
#    'epoch_maxspeed': np.float64(47.82349472215215)}],
#  [[2431, 2448],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(112.326),
#    'epoch_duration': np.float64(0.6810000000000116),
#    'epoch_distance': np.float64(17.035207369031557),
#    'epoch_meanspeed': np.float64(25.014988794465886),
#    'epoch_maxspeed': np.float64(40.093064550755756)}],
#  [[2457, 2477],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(113.368),
#    'epoch_duration': np.float64(0.8000000000000114),
#    'epoch_distance': np.float64(19.287997678085194),
#    'epoch_meanspeed': np.float64(24.10999709760615),
#    'epoch_maxspeed': np.float64(41.874729669525976)}],
#  [[2485, 2504],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(114.489),
#    'epoch_duration': np.float64(0.7590000000000003),
#    'epoch_distance': np.float64(18.51116871346146),
#    'epoch_meanspeed': np.float64(24.38889158558821),
#    'epoch_maxspeed': np.float64(41.52979252463174)}],
#  [[2511, 2528],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(115.53),
#    'epoch_duration': np.float64(0.679000000000002),
#    'epoch_distance': np.float64(16.72410323409786),
#    'epoch_meanspeed': np.float64(24.630490771867173),
#    'epoch_maxspeed': np.float64(55.33112242932358)}],
#  [[2571, 2591],
#   ['NE', 'N'],
#   ['NE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(117.929),
#    'epoch_duration': np.float64(0.8010000000000019),
#    'epoch_distance': np.float64(19.850786283801074),
#    'epoch_meanspeed': np.float64(24.782504723846476),
#    'epoch_maxspeed': np.float64(50.4264914342867)}],
#  [[2592, 2609],
#   ['NE', 'E'],
#   ['NE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(118.77),
#    'epoch_duration': np.float64(0.6809999999999974),
#    'epoch_distance': np.float64(20.91112501806216),
#    'epoch_meanspeed': np.float64(30.706497823879943),
#    'epoch_maxspeed': np.float64(62.4741580380138)}],
#  [[2635, 2654],
#   ['NW', 'S'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(120.491),
#    'epoch_duration': np.float64(0.7590000000000003),
#    'epoch_distance': np.float64(18.065406110291853),
#    'epoch_meanspeed': np.float64(23.801589078118372),
#    'epoch_maxspeed': np.float64(52.227058168294775)}],
#  [[2656, 2679],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(121.331),
#    'epoch_duration': np.float64(0.9209999999999923),
#    'epoch_distance': np.float64(12.79082832407433),
#    'epoch_meanspeed': np.float64(13.887978636345752),
#    'epoch_maxspeed': np.float64(33.420934695717506)}],
#  [[2729, 2752],
#   ['SW', 'N'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(124.253),
#    'epoch_duration': np.float64(0.9200000000000017),
#    'epoch_distance': np.float64(21.153297508063655),
#    'epoch_meanspeed': np.float64(22.992714682677843),
#    'epoch_maxspeed': np.float64(62.75038512120922)}],
#  [[2752, 2769],
#   ['SW', 'W'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(125.173),
#    'epoch_duration': np.float64(0.6799999999999926),
#    'epoch_distance': np.float64(18.01025825766781),
#    'epoch_meanspeed': np.float64(26.485673908335304),
#    'epoch_maxspeed': np.float64(52.99224247710973)}],
#  [[2772, 2787],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(125.972),
#    'epoch_duration': np.float64(0.6020000000000039),
#    'epoch_distance': np.float64(10.91176251266158),
#    'epoch_meanspeed': np.float64(18.125851349936063),
#    'epoch_maxspeed': np.float64(35.23469630417174)}],
#  [[2841, 2861],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(128.736),
#    'epoch_duration': np.float64(0.7990000000000066),
#    'epoch_distance': np.float64(9.69913180625517),
#    'epoch_meanspeed': np.float64(12.139088618592103),
#    'epoch_maxspeed': np.float64(33.47698641228186)}],
#  [[2862, 2878],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(129.576),
#    'epoch_duration': np.float64(0.63900000000001),
#    'epoch_distance': np.float64(17.958675072197057),
#    'epoch_meanspeed': np.float64(28.104342835988692),
#    'epoch_maxspeed': np.float64(54.51624341173846)}],
#  [[2880, 2898],
#   ['SE', 'N'],
#   ['SE', 'W'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(130.296),
#    'epoch_duration': np.float64(0.7210000000000036),
#    'epoch_distance': np.float64(11.304695205076932),
#    'epoch_meanspeed': np.float64(15.679188911341019),
#    'epoch_maxspeed': np.float64(32.684145154466854)}],
#  [[2904, 2925],
#   ['SE', 'W'],
#   ['SE', 'S'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(131.256),
#    'epoch_duration': np.float64(0.8410000000000082),
#    'epoch_distance': np.float64(17.709753219632912),
#    'epoch_meanspeed': np.float64(21.057970534640592),
#    'epoch_maxspeed': np.float64(51.47093486221321)}],
#  [[2931, 2951],
#   ['SE', 'S'],
#   ['SE', 'E'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(132.336),
#    'epoch_duration': np.float64(0.8019999999999925),
#    'epoch_distance': np.float64(19.061653775850388),
#    'epoch_meanspeed': np.float64(23.767648099564298),
#    'epoch_maxspeed': np.float64(61.37545161012411)}],
#  [[2954, 2974],
#   ['SE', 'E'],
#   ['SE', 'N'],
#   {'Rewarded': True,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(133.255),
#    'epoch_duration': np.float64(0.8029999999999973),
#    'epoch_distance': np.float64(17.379666737466557),
#    'epoch_meanspeed': np.float64(21.64342059460351),
#    'epoch_maxspeed': np.float64(55.69397924198887)}],
#  [[3006, 3028],
#   ['NE', 'W'],
#   ['NE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(135.339),
#    'epoch_duration': np.float64(0.8799999999999955),
#    'epoch_distance': np.float64(10.901661193274423),
#    'epoch_meanspeed': np.float64(12.388251355993727),
#    'epoch_maxspeed': np.float64(24.426704618482233)}],
#  [[3029, 3050],
#   ['NE', 'S'],
#   ['NE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(136.261),
#    'epoch_duration': np.float64(0.8389999999999986),
#    'epoch_distance': np.float64(18.407339234022416),
#    'epoch_meanspeed': np.float64(21.939617680598865),
#    'epoch_maxspeed': np.float64(60.72444159280773)}],
#  [[3051, 3068],
#   ['NE', 'E'],
#   ['NE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(137.14),
#    'epoch_duration': np.float64(0.6800000000000068),
#    'epoch_distance': np.float64(19.25767188645704),
#    'epoch_meanspeed': np.float64(28.320105715377714),
#    'epoch_maxspeed': np.float64(63.251725223440275)}],
#  [[3132, 3146],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(140.382),
#    'epoch_duration': np.float64(0.561000000000007),
#    'epoch_distance': np.float64(9.82325708901919),
#    'epoch_meanspeed': np.float64(17.510262190764823),
#    'epoch_maxspeed': np.float64(35.79639192088017)}],
#  [[3147, 3165],
#   ['SW', 'W'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(140.982),
#    'epoch_duration': np.float64(0.7189999999999941),
#    'epoch_distance': np.float64(16.881900904552122),
#    'epoch_meanspeed': np.float64(23.479695277541392),
#    'epoch_maxspeed': np.float64(36.13375645317694)}],
#  [[3165, 3183],
#   ['SW', 'N'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(141.701),
#    'epoch_duration': np.float64(0.7220000000000084),
#    'epoch_distance': np.float64(18.253808604319467),
#    'epoch_meanspeed': np.float64(25.28228338548373),
#    'epoch_maxspeed': np.float64(48.871422893514186)}],
#  [[3186, 3204],
#   ['SW', 'E'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(142.544),
#    'epoch_duration': np.float64(0.7189999999999941),
#    'epoch_distance': np.float64(19.393239106787536),
#    'epoch_meanspeed': np.float64(26.972516142959243),
#    'epoch_maxspeed': np.float64(50.930511938884635)}],
#  [[3205, 3219],
#   ['SW', 'S'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(143.305),
#    'epoch_duration': np.float64(0.556999999999988),
#    'epoch_distance': np.float64(10.265217354892659),
#    'epoch_meanspeed': np.float64(18.429474604834617),
#    'epoch_maxspeed': np.float64(37.65894008594852)}],
#  [[3243, 3258],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(144.822),
#    'epoch_duration': np.float64(0.6020000000000039),
#    'epoch_distance': np.float64(13.071381974923264),
#    'epoch_meanspeed': np.float64(21.71325909455678),
#    'epoch_maxspeed': np.float64(43.529945232916276)}],
#  [[3263, 3281],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(145.625),
#    'epoch_duration': np.float64(0.7199999999999989),
#    'epoch_distance': np.float64(18.467966491006646),
#    'epoch_meanspeed': np.float64(25.649953459731492),
#    'epoch_maxspeed': np.float64(54.30845786070002)}],
#  [[3283, 3300],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(146.426),
#    'epoch_duration': np.float64(0.6770000000000209),
#    'epoch_distance': np.float64(18.007383669083215),
#    'epoch_meanspeed': np.float64(26.598794193622833),
#    'epoch_maxspeed': np.float64(39.391671463864036)}],
#  [[3346, 3363],
#   ['NE', 'W'],
#   ['NE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(148.945),
#    'epoch_duration': np.float64(0.6810000000000116),
#    'epoch_distance': np.float64(19.81971887208864),
#    'epoch_meanspeed': np.float64(29.103845627148754),
#    'epoch_maxspeed': np.float64(48.971262648609034)}],
#  [[3366, 3382],
#   ['NE', 'N'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(149.747),
#    'epoch_duration': np.float64(0.6399999999999864),
#    'epoch_distance': np.float64(11.243033045050954),
#    'epoch_meanspeed': np.float64(17.56723913289249),
#    'epoch_maxspeed': np.float64(38.73476540753072)}],
#  [[3408, 3426],
#   ['NW', 'S'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(151.428),
#    'epoch_duration': np.float64(0.7189999999999941),
#    'epoch_distance': np.float64(18.26832378624043),
#    'epoch_meanspeed': np.float64(25.40796075972264),
#    'epoch_maxspeed': np.float64(51.641788730039785)}],
#  [[3426, 3466],
#   ['NW', 'W'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(152.147),
#    'epoch_duration': np.float64(1.6000000000000227),
#    'epoch_distance': np.float64(33.37764910614037),
#    'epoch_meanspeed': np.float64(20.861030691337433),
#    'epoch_maxspeed': np.float64(56.853107145468385)}],
#  [[3517, 3534],
#   ['NW', 'S'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(155.792),
#    'epoch_duration': np.float64(0.6779999999999973),
#    'epoch_distance': np.float64(12.462519909961644),
#    'epoch_meanspeed': np.float64(18.381297802303383),
#    'epoch_maxspeed': np.float64(39.83812475954956)}],
#  [[3542, 3567],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(156.79),
#    'epoch_duration': np.float64(1.0010000000000048),
#    'epoch_distance': np.float64(18.954159180199223),
#    'epoch_meanspeed': np.float64(18.93522395624289),
#    'epoch_maxspeed': np.float64(44.15688773953802)}],
#  [[3567, 3585],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(157.791),
#    'epoch_duration': np.float64(0.7189999999999941),
#    'epoch_distance': np.float64(20.277754640262973),
#    'epoch_meanspeed': np.float64(28.20271855391257),
#    'epoch_maxspeed': np.float64(56.06651367120291)}],
#  [[3586, 3602],
#   ['NW', 'E'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(158.551),
#    'epoch_duration': np.float64(0.6410000000000196),
#    'epoch_distance': np.float64(10.88548929913496),
#    'epoch_meanspeed': np.float64(16.982042588353554),
#    'epoch_maxspeed': np.float64(30.80179226773535)}],
#  [[3749, 3772],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(165.075),
#    'epoch_duration': np.float64(0.9200000000000159),
#    'epoch_distance': np.float64(19.08891755676994),
#    'epoch_meanspeed': np.float64(20.748823431271315),
#    'epoch_maxspeed': np.float64(49.20698149719689)}],
#  [[3794, 3815],
#   ['SW', 'E'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(166.876),
#    'epoch_duration': np.float64(0.8400000000000034),
#    'epoch_distance': np.float64(20.109648294319072),
#    'epoch_meanspeed': np.float64(23.940057493236893),
#    'epoch_maxspeed': np.float64(56.322907396870434)}],
#  [[3817, 3832],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(12)},
#   {'epoch_time': np.float64(167.798),
#    'epoch_duration': np.float64(0.5989999999999895),
#    'epoch_distance': np.float64(17.448813657692742),
#    'epoch_meanspeed': np.float64(29.129905939387392),
#    'epoch_maxspeed': np.float64(59.55759115588624)}],
#  [[3858, 3877],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(8)},
#   {'epoch_time': np.float64(169.437),
#    'epoch_duration': np.float64(0.7620000000000005),
#    'epoch_distance': np.float64(11.235442625945023),
#    'epoch_meanspeed': np.float64(14.744675362132567),
#    'epoch_maxspeed': np.float64(33.552954514521986)}],
#  [[3958, 3976],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(173.439),
#    'epoch_duration': np.float64(0.7189999999999941),
#    'epoch_distance': np.float64(9.588920356231277),
#    'epoch_meanspeed': np.float64(13.336467811170175),
#    'epoch_maxspeed': np.float64(28.59658831920869)}],
#  [[3981, 4000],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(174.36),
#    'epoch_duration': np.float64(0.7579999999999814),
#    'epoch_distance': np.float64(18.908584702052135),
#    'epoch_meanspeed': np.float64(24.945362403763326),
#    'epoch_maxspeed': np.float64(45.86965046465762)}],
#  [[4003, 4022],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(175.238),
#    'epoch_duration': np.float64(0.7599999999999909),
#    'epoch_distance': np.float64(19.484801399368063),
#    'epoch_meanspeed': np.float64(25.63789657811618),
#    'epoch_maxspeed': np.float64(49.57690206750904)}],
#  [[4046, 4061],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(176.962),
#    'epoch_duration': np.float64(0.5970000000000084),
#    'epoch_distance': np.float64(16.532487575009007),
#    'epoch_meanspeed': np.float64(27.69260900336478),
#    'epoch_maxspeed': np.float64(54.06799782184709)}],
#  [[4085, 4103],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(178.521),
#    'epoch_duration': np.float64(0.7230000000000132),
#    'epoch_distance': np.float64(18.973063031567165),
#    'epoch_meanspeed': np.float64(26.242134206869736),
#    'epoch_maxspeed': np.float64(48.33788265038146)}],
#  [[4110, 4128],
#   ['NW', 'N'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(179.522),
#    'epoch_duration': np.float64(0.7220000000000084),
#    'epoch_distance': np.float64(11.064263303545285),
#    'epoch_meanspeed': np.float64(15.324464409342323),
#    'epoch_maxspeed': np.float64(35.64069432093204)}],
#  [[4130, 4148],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(180.321),
#    'epoch_duration': np.float64(0.7210000000000036),
#    'epoch_distance': np.float64(21.601142716573012),
#    'epoch_meanspeed': np.float64(29.959976028533845),
#    'epoch_maxspeed': np.float64(72.37264807516233)}],
#  [[4151, 4167],
#   ['NW', 'S'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(181.162),
#    'epoch_duration': np.float64(0.6419999999999959),
#    'epoch_distance': np.float64(18.056471833409862),
#    'epoch_meanspeed': np.float64(28.125345534906508),
#    'epoch_maxspeed': np.float64(59.788189947737095)}],
#  [[4243, 4261],
#   ['NE', 'W'],
#   ['NE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(184.845),
#    'epoch_duration': np.float64(0.7220000000000084),
#    'epoch_distance': np.float64(18.86691793862727),
#    'epoch_meanspeed': np.float64(26.131465288957134),
#    'epoch_maxspeed': np.float64(45.74619396154514)}],
#  [[4263, 4279],
#   ['NE', 'N'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(185.645),
#    'epoch_duration': np.float64(0.6419999999999959),
#    'epoch_distance': np.float64(11.138010999006529),
#    'epoch_meanspeed': np.float64(17.348926789729905),
#    'epoch_maxspeed': np.float64(33.172361635020586)}],
#  [[4331, 4347],
#   ['SW', 'E'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(188.368),
#    'epoch_duration': np.float64(0.6400000000000148),
#    'epoch_distance': np.float64(17.655523874976254),
#    'epoch_meanspeed': np.float64(27.586756054649758),
#    'epoch_maxspeed': np.float64(61.4626482762354)}],
#  [[4369, 4399],
#   ['SW', 'E'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(189.89),
#    'epoch_duration': np.float64(1.1990000000000123),
#    'epoch_distance': np.float64(21.43466788335657),
#    'epoch_meanspeed': np.float64(17.87712083682765),
#    'epoch_maxspeed': np.float64(31.820796031852126)}],
#  [[4399, 4416],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(191.089),
#    'epoch_duration': np.float64(0.6800000000000068),
#    'epoch_distance': np.float64(17.44080906486961),
#    'epoch_meanspeed': np.float64(25.648248624807994),
#    'epoch_maxspeed': np.float64(53.0802268425342)}],
#  [[4474, 4494],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(8)},
#   {'epoch_time': np.float64(194.089),
#    'epoch_duration': np.float64(0.8019999999999925),
#    'epoch_distance': np.float64(10.470341392357993),
#    'epoch_meanspeed': np.float64(13.05528851914974),
#    'epoch_maxspeed': np.float64(30.02511662137031)}],
#  [[4499, 4517],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(8)},
#   {'epoch_time': np.float64(195.091),
#    'epoch_duration': np.float64(0.7199999999999989),
#    'epoch_distance': np.float64(16.559656014660632),
#    'epoch_meanspeed': np.float64(22.99952224258425),
#    'epoch_maxspeed': np.float64(50.795614781720595)}],
#  [[4518, 4535],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(8)},
#   {'epoch_time': np.float64(195.85),
#    'epoch_duration': np.float64(0.6820000000000164),
#    'epoch_distance': np.float64(17.537069866722714),
#    'epoch_meanspeed': np.float64(25.71417869020864),
#    'epoch_maxspeed': np.float64(51.483721802640005)}],
#  [[4539, 4556],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(8)},
#   {'epoch_time': np.float64(196.692),
#    'epoch_duration': np.float64(0.679000000000002),
#    'epoch_distance': np.float64(19.036831080194194),
#    'epoch_meanspeed': np.float64(28.036570073923617),
#    'epoch_maxspeed': np.float64(47.73190987241505)}],
#  [[4622, 4657],
#   ['NW', 'W'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(200.014),
#    'epoch_duration': np.float64(1.4029999999999916),
#    'epoch_distance': np.float64(37.661615654898995),
#    'epoch_meanspeed': np.float64(26.843631970705076),
#    'epoch_maxspeed': np.float64(56.95994689130778)}],
#  [[4806, 4822],
#   ['NW', 'S'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(207.376),
#    'epoch_duration': np.float64(0.6389999999999816),
#    'epoch_distance': np.float64(7.430394092755713),
#    'epoch_meanspeed': np.float64(11.628159769571091),
#    'epoch_maxspeed': np.float64(19.71148120230697)}],
#  [[4831, 4851],
#   ['NW', 'E'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(208.378),
#    'epoch_duration': np.float64(0.8000000000000114),
#    'epoch_distance': np.float64(18.171525914023032),
#    'epoch_meanspeed': np.float64(22.714407392528468),
# ...
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(550.841),
#    'epoch_duration': np.float64(0.7200000000000273),
#    'epoch_distance': np.float64(17.624236191086112),
#    'epoch_meanspeed': np.float64(24.478105820952006),
#    'epoch_maxspeed': np.float64(49.446824272789904)}],
#  [[13411, 13434],
#   ['NW', 'E'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(551.762),
#    'epoch_duration': np.float64(0.9200000000000728),
#    'epoch_distance': np.float64(19.847149135492394),
#    'epoch_meanspeed': np.float64(21.572988190750895),
#    'epoch_maxspeed': np.float64(48.416131523655636)}],
#  [[13437, 13454],
#   ['NW', 'N'],
#   ['NW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(552.802),
#    'epoch_duration': np.float64(0.6809999999999263),
#    'epoch_distance': np.float64(18.502854563918955),
#    'epoch_meanspeed': np.float64(27.170124176095385),
#    'epoch_maxspeed': np.float64(60.89323941917522)}],
#  [[13500, 13516],
#   ['SW', 'E'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(555.324),
#    'epoch_duration': np.float64(0.6370000000000573),
#    'epoch_distance': np.float64(8.045810097417796),
#    'epoch_meanspeed': np.float64(12.630785082287398),
#    'epoch_maxspeed': np.float64(35.997688550512805)}],
#  [[13521, 13539],
#   ['SW', 'N'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(556.164),
#    'epoch_duration': np.float64(0.7200000000000273),
#    'epoch_distance': np.float64(20.000237004635476),
#    'epoch_meanspeed': np.float64(27.778106950881554),
#    'epoch_maxspeed': np.float64(67.43360666011299)}],
#  [[15308, 15327],
#   ['NE', 'S'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(627.679),
#    'epoch_duration': np.float64(0.7649999999999864),
#    'epoch_distance': np.float64(20.798154011979022),
#    'epoch_meanspeed': np.float64(27.187129427424043),
#    'epoch_maxspeed': np.float64(61.47429607476322)}],
#  [[15331, 15347],
#   ['NE', 'W'],
#   ['NE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(628.604),
#    'epoch_duration': np.float64(0.6399999999999864),
#    'epoch_distance': np.float64(11.406555802766691),
#    'epoch_meanspeed': np.float64(17.822743441823334),
#    'epoch_maxspeed': np.float64(32.44015661021993)}],
#  [[15351, 15376],
#   ['NE', 'S'],
#   ['NE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(629.401),
#    'epoch_duration': np.float64(1.0020000000000664),
#    'epoch_distance': np.float64(19.820812392590238),
#    'epoch_meanspeed': np.float64(19.781249892803316),
#    'epoch_maxspeed': np.float64(44.92263274646739)}],
#  [[15377, 15409],
#   ['NE', 'E'],
#   ['NE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(630.441),
#    'epoch_duration': np.float64(1.2830000000000155),
#    'epoch_distance': np.float64(31.686196562252686),
#    'epoch_meanspeed': np.float64(24.696957569955032),
#    'epoch_maxspeed': np.float64(62.10677578184045)}],
#  [[15409, 15427],
#   ['NE', 'W'],
#   ['NE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(11)},
#   {'epoch_time': np.float64(631.724),
#    'epoch_duration': np.float64(0.7210000000000036),
#    'epoch_distance': np.float64(19.95061608381615),
#    'epoch_meanspeed': np.float64(27.670757397803122),
#    'epoch_maxspeed': np.float64(60.36517163993)}],
#  [[15843, 15856],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(649.093),
#    'epoch_duration': np.float64(0.5200000000000955),
#    'epoch_distance': np.float64(19.984219396976147),
#    'epoch_meanspeed': np.float64(38.431191148024),
#    'epoch_maxspeed': np.float64(65.02378932601286)}],
#  [[15954, 15977],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(653.536),
#    'epoch_duration': np.float64(0.9210000000000491),
#    'epoch_distance': np.float64(7.447728338787654),
#    'epoch_meanspeed': np.float64(8.086567143091484),
#    'epoch_maxspeed': np.float64(16.761714434309358)}],
#  [[16029, 16059],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(656.537),
#    'epoch_duration': np.float64(1.2010000000000218),
#    'epoch_distance': np.float64(13.17908576272569),
#    'epoch_meanspeed': np.float64(10.973426946482473),
#    'epoch_maxspeed': np.float64(30.292118062352245)}],
#  [[16060, 16085],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(657.779),
#    'epoch_duration': np.float64(0.9990000000000236),
#    'epoch_distance': np.float64(17.059111628506294),
#    'epoch_meanspeed': np.float64(17.07618781632221),
#    'epoch_maxspeed': np.float64(45.14493626933741)}],
#  [[16088, 16107],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': True,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(658.899),
#    'epoch_duration': np.float64(0.7599999999999909),
#    'epoch_distance': np.float64(17.135354828294577),
#    'epoch_meanspeed': np.float64(22.546519510914187),
#    'epoch_maxspeed': np.float64(38.56803022777331)}],
#  [[16124, 16147],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(660.34),
#    'epoch_duration': np.float64(0.9180000000000064),
#    'epoch_distance': np.float64(19.15309861964945),
#    'epoch_meanspeed': np.float64(20.863941851469846),
#    'epoch_maxspeed': np.float64(40.78420674361405)}],
#  [[16148, 16166],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(661.299),
#    'epoch_duration': np.float64(0.7190000000000509),
#    'epoch_distance': np.float64(17.879261832033045),
#    'epoch_meanspeed': np.float64(24.8668453853015),
#    'epoch_maxspeed': np.float64(43.28103989383203)}],
#  [[16201, 16217],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(663.424),
#    'epoch_duration': np.float64(0.6380000000000337),
#    'epoch_distance': np.float64(16.904291272053637),
#    'epoch_meanspeed': np.float64(26.49575434491026),
#    'epoch_maxspeed': np.float64(48.236350674489884)}],
#  [[16218, 16236],
#   ['SW', 'W'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(664.102),
#    'epoch_duration': np.float64(0.7190000000000509),
#    'epoch_distance': np.float64(9.863926281257115),
#    'epoch_meanspeed': np.float64(13.718951712456768),
#    'epoch_maxspeed': np.float64(33.11483474422312)}],
#  [[16243, 16260],
#   ['SW', 'S'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(6)},
#   {'epoch_time': np.float64(665.102),
#    'epoch_duration': np.float64(0.6800000000000637),
#    'epoch_distance': np.float64(18.246403509111573),
#    'epoch_meanspeed': np.float64(26.832946336926273),
#    'epoch_maxspeed': np.float64(67.82545261144111)}],
#  [[16291, 16314],
#   ['NW', 'W'],
#   ['NW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(667.023),
#    'epoch_duration': np.float64(0.9209999999999354),
#    'epoch_distance': np.float64(19.492856049419974),
#    'epoch_meanspeed': np.float64(21.164881704040543),
#    'epoch_maxspeed': np.float64(37.4021869808924)}],
#  [[16318, 16334],
#   ['NW', 'N'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(7)},
#   {'epoch_time': np.float64(668.104),
#    'epoch_duration': np.float64(0.63900000000001),
#    'epoch_distance': np.float64(21.37468638538016),
#    'epoch_meanspeed': np.float64(33.450213435649175),
#    'epoch_maxspeed': np.float64(70.69075550834296)}],
#  [[16366, 16382],
#   ['SW', 'W'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(670.025),
#    'epoch_duration': np.float64(0.63900000000001),
#    'epoch_distance': np.float64(10.474392706196166),
#    'epoch_meanspeed': np.float64(16.391850870416278),
#    'epoch_maxspeed': np.float64(30.918493256940494)}],
#  [[16386, 16407],
#   ['SW', 'N'],
#   ['SW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(670.826),
#    'epoch_duration': np.float64(0.8389999999999418),
#    'epoch_distance': np.float64(19.497105904924837),
#    'epoch_meanspeed': np.float64(23.23850525021),
#    'epoch_maxspeed': np.float64(40.58296809939132)}],
#  [[16422, 16434],
#   ['SW', 'E'],
#   ['SW', 'N'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(672.265),
#    'epoch_duration': np.float64(0.48099999999999454),
#    'epoch_distance': np.float64(6.3847074760720055),
#    'epoch_meanspeed': np.float64(13.273820116573967),
#    'epoch_maxspeed': np.float64(25.61692475412378)}],
#  [[16462, 16496],
#   ['SW', 'N'],
#   ['SW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(9)},
#   {'epoch_time': np.float64(673.869),
#    'epoch_duration': np.float64(1.3579999999999472),
#    'epoch_distance': np.float64(26.57039949198248),
#    'epoch_meanspeed': np.float64(19.565831731946624),
#    'epoch_maxspeed': np.float64(46.236875033254734)}],
#  [[16531, 16550],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(676.629),
#    'epoch_duration': np.float64(0.7609999999999673),
#    'epoch_distance': np.float64(10.99984010295497),
#    'epoch_meanspeed': np.float64(14.454454800204262),
#    'epoch_maxspeed': np.float64(29.4705263208244)}],
#  [[16551, 16569],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(677.429),
#    'epoch_duration': np.float64(0.7180000000000746),
#    'epoch_distance': np.float64(16.419187152217017),
#    'epoch_meanspeed': np.float64(22.867948679965615),
#    'epoch_maxspeed': np.float64(43.54850989590578)}],
#  [[16569, 16602],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(678.147),
#    'epoch_duration': np.float64(1.322999999999979),
#    'epoch_distance': np.float64(20.095231750017387),
#    'epoch_meanspeed': np.float64(15.18913964476017),
#    'epoch_maxspeed': np.float64(40.76243511750253)}],
#  [[16693, 16713],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(683.114),
#    'epoch_duration': np.float64(0.7999999999999545),
#    'epoch_distance': np.float64(12.164128436326608),
#    'epoch_meanspeed': np.float64(15.205160545409125),
#    'epoch_maxspeed': np.float64(30.405178370425144)}],
#  [[16714, 16739],
#   ['SE', 'E'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(683.953),
#    'epoch_duration': np.float64(1.0),
#    'epoch_distance': np.float64(18.09935462083),
#    'epoch_meanspeed': np.float64(18.09935462083),
#    'epoch_maxspeed': np.float64(32.605264676570194)}],
#  [[16754, 16770],
#   ['SE', 'S'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(685.554),
#    'epoch_duration': np.float64(0.6399999999999864),
#    'epoch_distance': np.float64(9.434476874910839),
#    'epoch_meanspeed': np.float64(14.7413701170485),
#    'epoch_maxspeed': np.float64(27.295739956402425)}],
#  [[16770, 16802],
#   ['SE', 'W'],
#   ['SE', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 2,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(686.194),
#    'epoch_duration': np.float64(1.2800000000000864),
#    'epoch_distance': np.float64(28.808898162023894),
#    'epoch_meanspeed': np.float64(22.50695168907965),
#    'epoch_maxspeed': np.float64(44.36802755700439)}],
#  [[16805, 16823],
#   ['SE', 'W'],
#   ['SE', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(687.594),
#    'epoch_duration': np.float64(0.7179999999999609),
#    'epoch_distance': np.float64(16.26031005952866),
#    'epoch_meanspeed': np.float64(22.64667139210243),
#    'epoch_maxspeed': np.float64(39.32122978393498)}],
#  [[16882, 16894],
#   ['SE', 'W'],
#   ['SE', 'N'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(690.675),
#    'epoch_duration': np.float64(0.48099999999999454),
#    'epoch_distance': np.float64(11.286416841933196),
#    'epoch_meanspeed': np.float64(23.46448407886346),
#    'epoch_maxspeed': np.float64(56.19021133156897)}],
#  [[16917, 16934],
#   ['SE', 'N'],
#   ['SE', 'E'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(5)},
#   {'epoch_time': np.float64(692.077),
#    'epoch_duration': np.float64(0.67999999999995),
#    'epoch_distance': np.float64(9.42582929424069),
#    'epoch_meanspeed': np.float64(13.861513668002036),
#    'epoch_maxspeed': np.float64(31.590931996340075)}],
#  [[16976, 16993],
#   ['SW', 'S'],
#   ['SW', 'W'],
#   {'Rewarded': False,
#    'direction': 'CW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(10)},
#   {'epoch_time': np.float64(694.437),
#    'epoch_duration': np.float64(0.6839999999999691),
#    'epoch_distance': np.float64(17.311702289327805),
#    'epoch_meanspeed': np.float64(25.309506270948226),
#    'epoch_maxspeed': np.float64(49.12530060358311)}],
#  [[17013, 17032],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(695.918),
#    'epoch_duration': np.float64(0.7609999999999673),
#    'epoch_distance': np.float64(13.029448895384949),
#    'epoch_meanspeed': np.float64(17.12148343677465),
#    'epoch_maxspeed': np.float64(40.34571924434903)}],
#  [[17555, 17574],
#   ['NW', 'W'],
#   ['NW', 'S'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(717.61),
#    'epoch_duration': np.float64(0.7599999999999909),
#    'epoch_distance': np.float64(11.026966414030472),
#    'epoch_meanspeed': np.float64(14.509166334250795),
#    'epoch_maxspeed': np.float64(30.02443677864293)}],
#  [[17579, 17606],
#   ['NW', 'S'],
#   ['NW', 'E'],
#   {'Rewarded': False,
#    'direction': 'CCW',
#    'num_trapezeswitch': 1,
#    'max_rewards': np.int64(4)},
#   {'epoch_time': np.float64(718.569),
#    'epoch_duration': np.float64(1.0830000000000837),
#    'epoch_distance': np.float64(22.985955574715895),
#    'epoch_meanspeed': np.float64(21.224335710724024),
#    'epoch_maxspeed': np.float64(59.15793543162327)}]]

# %%
session_traj_df, session_turns_df, session_param_df = load_data(folder_path_mouse_to_process,'MOU4551_20240804-1201')
turn_idx = session_turns_df.loc[session_turns_df['framenumber'] == 65]
turn_idx
# Out:
# Empty DataFrame
# Columns: [time, framenumber, xposition, yposition, currentPatch, previousTrapeze, currentTrapeze, turnDirection, ongoingRewardedObject, ongoingRewardedDirection, Rewarded, nberOfConsecRewards, maxNberOfConsecRewards, typeOfTurn, totalnberOfRewards]
# Index: []

# %%
l = len(session_turns_df)

#s = 

session_turns_df[:5][[True,True,False,False,False]]['ongoingRewardedDirection'].iat[0]
# Out:
# '[90.0]'

# %%
session_turns_df
# Out:
#         time  framenumber  xposition  yposition currentPatch previousTrapeze  \
# 5     16.997          421         96        198           NW               S
# 6     18.037          447         97        107           NW               W
# 7     18.877          468        193        114           NW               N
# 8     19.518          484        194        215           NW               E
# 9     20.157          500         99        334           SW               N
# ..       ...          ...        ...        ...          ...             ...
# 591  696.320        17395        102        210           NW               W
# 592  716.290        17894        104        415           SW               S
# 593  717.090        17914         95        201           NW               S
# 594  718.091        17939         87        214           NW               W
# 595  719.051        17963        209        220           NW               S
#
#     currentTrapeze  turnDirection ongoingRewardedObject  \
# 5                W          270.0                ['NW']
# 6                N          270.0                ['NW']
# 7                E          270.0                ['NW']
# 8                S          270.0                ['NW']
# 9                W           90.0                ['NW']
# ..             ...            ...                   ...
# 591              S           90.0                ['NE']
# 592              W          270.0                ['NE']
# 593              W          270.0                ['NE']
# 594              S           90.0                ['NE']
# 595              E           90.0                ['NE']
#
#     ongoingRewardedDirection  Rewarded  nberOfConsecRewards  \
# 5                     [90.0]     False                    0
# 6                     [90.0]     False                    0
# 7                     [90.0]     False                    0
# 8                     [90.0]     False                    0
# 9                     [90.0]     False                    0
# ..                       ...       ...                  ...
# 591                  [[270]]     False                    0
# 592                  [[270]]     False                    0
# 593                  [[270]]     False                    0
# 594                  [[270]]     False                    0
# 595                  [[270]]     False                    0
#
#      maxNberOfConsecRewards typeOfTurn  totalnberOfRewards
# 5                         9       gobd                   2
# 6                         9       gobd                   2
# 7                         9       gobd                   2
# 8                         9       gobd                   2
# 9                        11       bogd                   2
# ..                      ...        ...                 ...
# 591                       4       bobd                 144
# 592                      11       bogd                 144
# 593                       4       bogd                 144
# 594                       4       bobd                 144
# 595                       4       bobd                 144
#
# [591 rows x 15 columns]

# %%
'/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/MOU4551/MOU4551_20240806-1200/MOU4551_20240806-1200_basic_processing_output.pickle' == '/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/MOU4551/MOU4551_20240804-1201/MOU4551_20240806-1200_basic_processing_output.pickle'
# Out:
# False

# %%
session_data['all_epochs']['run_around_tower'][0]
# Out:
# [[9, 24],
#  ['SW', 'E'],
#  ['SW', 'N'],
#  {'Rewarded': False,
#   'direction': 'CCW',
#   'num_trapezeswitch': 1,
#   'max_rewards': np.int64(8)},
#  {'epoch_time': np.float64(15.38),
#   'epoch_duration': np.float64(0.6009999999999991),
#   'epoch_distance': np.float64(17.741486508850432),
#   'epoch_meanspeed': np.float64(29.51994427429361),
#   'epoch_maxspeed': np.float64(62.68376700269201)}]

# %%
session_traj_df, session_turns_df, session_param_df = load_data(folder_path_mouse_to_process,'MOU4551_20240804-1201')
turn_idx = session_turns_df.loc[session_turns_df['time'] == 18.037]
turn_idx
# Out:
#      time  framenumber  xposition  yposition currentPatch previousTrapeze  \
# 6  18.037          447         97        107           NW               W
#
#   currentTrapeze  turnDirection ongoingRewardedObject  \
# 6              N          270.0                ['NW']
#
#   ongoingRewardedDirection  Rewarded  nberOfConsecRewards  \
# 6                   [90.0]     False                    0
#
#    maxNberOfConsecRewards typeOfTurn  totalnberOfRewards
# 6                       9       gobd                   2

# %%
session_turns_df
# Out:
#         time  framenumber  xposition  yposition currentPatch previousTrapeze  \
# 5     16.997          421         96        198           NW               S
# 6     18.037          447         97        107           NW               W
# 7     18.877          468        193        114           NW               N
# 8     19.518          484        194        215           NW               E
# 9     20.157          500         99        334           SW               N
# ..       ...          ...        ...        ...          ...             ...
# 591  696.320        17395        102        210           NW               W
# 592  716.290        17894        104        415           SW               S
# 593  717.090        17914         95        201           NW               S
# 594  718.091        17939         87        214           NW               W
# 595  719.051        17963        209        220           NW               S
#
#     currentTrapeze  turnDirection ongoingRewardedObject  \
# 5                W          270.0                ['NW']
# 6                N          270.0                ['NW']
# 7                E          270.0                ['NW']
# 8                S          270.0                ['NW']
# 9                W           90.0                ['NW']
# ..             ...            ...                   ...
# 591              S           90.0                ['NE']
# 592              W          270.0                ['NE']
# 593              W          270.0                ['NE']
# 594              S           90.0                ['NE']
# 595              E           90.0                ['NE']
#
#     ongoingRewardedDirection  Rewarded  nberOfConsecRewards  \
# 5                     [90.0]     False                    0
# 6                     [90.0]     False                    0
# 7                     [90.0]     False                    0
# 8                     [90.0]     False                    0
# 9                     [90.0]     False                    0
# ..                       ...       ...                  ...
# 591                  [[270]]     False                    0
# 592                  [[270]]     False                    0
# 593                  [[270]]     False                    0
# 594                  [[270]]     False                    0
# 595                  [[270]]     False                    0
#
#      maxNberOfConsecRewards typeOfTurn  totalnberOfRewards
# 5                         9       gobd                   2
# 6                         9       gobd                   2
# 7                         9       gobd                   2
# 8                         9       gobd                   2
# 9                        11       bogd                   2
# ..                      ...        ...                 ...
# 591                       4       bobd                 144
# 592                      11       bogd                 144
# 593                       4       bogd                 144
# 594                       4       bobd                 144
# 595                       4       bobd                 144
#
# [591 rows x 15 columns]

# %%
session_turns_df['time']
# Out:
# 9       15.612
# 10      16.651
# 11      17.413
# 12      18.933
# 13      22.015
#         ...
# 537    708.220
# 538    710.702
# 539    714.585
# 540    716.306
# 541    718.787
# Name: time, Length: 533, dtype: float64

# %%
session_list[mice_to_compare[0]][sessions_to_compare[0]]
# Out:
# 'MOU4551_20240804-1201'

# %%
folder_path_mouse_to_process
# Out:
# '/LocalData/ForagingMice/4TowerTaskMethodPaper/MaudData/MOU4551'

# %%
session_turns_df.loc[session_turns_df['time'] == time_of_turn].index[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 session_turns_df.loc[session_turns_df['time'] == time_of_turn].index[0]
#
# NameError: name 'time_of_turn' is not defined

# %%
session_turns_df['time']
# Out:
# 9       15.612
# 10      16.651
# 11      17.413
# 12      18.933
# 13      22.015
#         ...
# 537    708.220
# 538    710.702
# 539    714.585
# 540    716.306
# 541    718.787
# Name: time, Length: 533, dtype: float64

# %%
CW_mice
# Out:
# ['MOU3975',
#  'MOU3988',
#  'MOU3991',
#  'MOU4122',
#  'MOU4123',
#  'MOU4124',
#  'MOU4551',
#  'MOU4552',
#  'MOU4623']
